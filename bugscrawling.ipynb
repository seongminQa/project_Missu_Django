# %%
import requests
from bs4 import BeautifulSoup
import json
import os
os.environ.setdefault("DJANGO_SETTINGS_MODULE", "config.settings")

import django
django.setup()

from music.models import BugsWeekTop

def parse_music():
  header = {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/39.0.2171.95 Safari/537.36'}
  req = requests.get('https://music.bugs.co.kr/chart/track/week/total',headers = header)
  soup = BeautifulSoup(req.content,'html.parser')
  bugscharts = soup.select('#CHARTweek > table > tbody > tr')
  
  data = []
  # data = {}
  for idx, bugschart in enumerate(bugscharts):
    # 순위
    rank = bugschart.select('td > div.ranking > strong')[0].text
    # 앨범표지
    image = 'Bugs/Bugs{}.jpg'.format((idx+1))
    # 가수
    title = bugschart.select('th > p.title > a')[0].text
    # 곡 제목 찾기
    musician = bugschart.select('td > p.artist > a')[0].text
    # 앨범
    album = bugschart.select('td > a.album')[0].text
    album_link = bugschart.select_one('td > a.album').attrs['href']
    data.append([rank,image,title,musician,album,album_link])
    # data[str(rank)] = {'rank':rank,'title':title,'musician':musician,'album':album}

  return data 

parse_music()
# Out:
# [['1',
#   'Bugs/Bugs1.jpg',
#   'Ditto',
#   'NewJeans',
#   "NewJeans 'OMG'",
#   'https://music.bugs.co.kr/album/4082425?wl_ref=list_tr_11_chart'],
#  ['2',
#   'Bugs/Bugs2.jpg',
#   'OMG',
#   'NewJeans',
#   "NewJeans 'OMG'",
#   'https://music.bugs.co.kr/album/4082425?wl_ref=list_tr_11_chart'],
#  ['3',
#   'Bugs/Bugs3.jpg',
#   'Hype Boy',
#   'NewJeans',
#   "NewJeans 1st EP 'New Jeans'",
#   'https://music.bugs.co.kr/album/4078016?wl_ref=list_tr_11_chart'],
#  ['4',
#   'Bugs/Bugs4.jpg',
#   'VIBE (feat. Jimin of BTS)',
#   '태양',
#   'VIBE (feat. Jimin of BTS)',
#   'https://music.bugs.co.kr/album/4083071?wl_ref=list_tr_11_chart'],
#  ['5',
#   'Bugs/Bugs5.jpg',
#   'Attention',
#   'NewJeans',
#   "NewJeans 1st EP 'New Jeans'",
#   'https://music.bugs.co.kr/album/4078016?wl_ref=list_tr_11_chart'],
#  ['6',
#   'Bugs/Bugs6.jpg',
#   '사건의 지평선',
#   '윤하(Younha/ユンナ)',
#   "YOUNHA 6th Album Repackage 'END THEORY : Final Edition'",
#   'https://music.bugs.co.kr/album/4073469?wl_ref=list_tr_11_chart'],
#  ['7',
#   'Bugs/Bugs7.jpg',
#   'ANTIFRAGILE',
#   'LE SSERAFIM (르세라핌)',
#   'ANTIFRAGILE',
#   'https://music.bugs.co.kr/album/4080706?wl_ref=list_tr_11_chart'],
#  ['8',
#   'Bugs/Bugs8.jpg',
#   'After LIKE',
#   'IVE (아이브)',
#   'After LIKE',
#   'https://music.bugs.co.kr/album/4078936?wl_ref=list_tr_11_chart'],
#  ['9',
#   'Bugs/Bugs9.jpg',
#   'Candy',
#   'NCT DREAM',
#   'Candy - Winter Special Mini Album',
#   'https://music.bugs.co.kr/album/20535111?wl_ref=list_tr_11_chart'],
#  ['10',
#   'Bugs/Bugs10.jpg',
#   'Rush Hour (Feat. j-hope of BTS)',
#   'Crush',
#   'Rush Hour',
#   'https://music.bugs.co.kr/album/20494485?wl_ref=list_tr_11_chart'],
#  ['11',
#   'Bugs/Bugs11.jpg',
#   'I Don’t Think That I Like Her',
#   'Charlie Puth(찰리 푸스)',
#   'I Don’t Think That I Like Her',
#   'https://music.bugs.co.kr/album/4079758?wl_ref=list_tr_11_chart'],
#  ['12',
#   'Bugs/Bugs12.jpg',
#   'Dreamers [Music from the FIFA World Cup Qatar 2022 Official Soundtrack] (feat. FIFA Sound)',
#   '정국',
#   'Dreamers [Music from the FIFA World Cup Qatar 2022 Official Soundtrack]',
#   'https://music.bugs.co.kr/album/30064007?wl_ref=list_tr_11_chart'],
#  ['13',
#   'Bugs/Bugs13.jpg',
#   'LOVE DIVE',
#   'IVE (아이브)',
#   'LOVE DIVE',
#   'https://music.bugs.co.kr/album/4073710?wl_ref=list_tr_11_chart'],
#  ['14',
#   'Bugs/Bugs14.jpg',
#   'Cookie',
#   'NewJeans',
#   "NewJeans 1st EP 'New Jeans'",
#   'https://music.bugs.co.kr/album/4078016?wl_ref=list_tr_11_chart'],
#  ['15',
#   'Bugs/Bugs15.jpg',
#   '오르트구름',
#   '윤하(Younha/ユンナ)',
#   "YOUNHA 6th Album 'END THEORY'",
#   'https://music.bugs.co.kr/album/4067509?wl_ref=list_tr_11_chart'],
#  ['16',
#   'Bugs/Bugs16.jpg',
#   'Unholy',
#   'Sam Smith(샘 스미스)',
#   'Unholy',
#   'https://music.bugs.co.kr/album/19432437?wl_ref=list_tr_11_chart'],
#  ['17',
#   'Bugs/Bugs17.jpg',
#   'Left and Right (Feat. Jung Kook of BTS)',
#   'Charlie Puth(찰리 푸스)',
#   'Left and Right (Feat. Jung Kook of BTS)',
#   'https://music.bugs.co.kr/album/4077049?wl_ref=list_tr_11_chart'],
#  ['18',
#   'Bugs/Bugs18.jpg',
#   'WHEN I MOVE',
#   '카라(Kara)',
#   'MOVE AGAIN',
#   'https://music.bugs.co.kr/album/20530901?wl_ref=list_tr_11_chart'],
#  ['19',
#   'Bugs/Bugs19.jpg',
#   'Nxde',
#   '(여자)아이들',
#   'I love',
#   'https://music.bugs.co.kr/album/4080705?wl_ref=list_tr_11_chart'],
#  ['20',
#   'Bugs/Bugs20.jpg',
#   'NOT SORRY (Feat. pH-1) (Prod. by Slom)',
#   '이영지',
#   '쇼미더머니 11 Episode 3',
#   'https://music.bugs.co.kr/album/20535217?wl_ref=list_tr_11_chart'],
#  ['21',
#   'Bugs/Bugs21.jpg',
#   'Shut Down',
#   'BLACKPINK',
#   'BORN PINK',
#   'https://music.bugs.co.kr/album/4078880?wl_ref=list_tr_11_chart'],
#  ['22',
#   'Bugs/Bugs22.jpg',
#   'FEARLESS',
#   'LE SSERAFIM (르세라핌)',
#   'FEARLESS',
#   'https://music.bugs.co.kr/album/4075173?wl_ref=list_tr_11_chart'],
#  ['23',
#   'Bugs/Bugs23.jpg',
#   '혼자서 걸어요 (Prod. by 나얼)',
#   '태연 (TAEYEON)',
#   '나얼 <Ballad Pop City>',
#   'https://music.bugs.co.kr/album/4083499?wl_ref=list_tr_11_chart'],
#  ['24',
#   'Bugs/Bugs24.jpg',
#   'That That (prod. & feat. SUGA of BTS)',
#   '싸이 (PSY)',
#   '싸다9',
#   'https://music.bugs.co.kr/album/20465114?wl_ref=list_tr_11_chart'],
#  ['25',
#   'Bugs/Bugs25.jpg',
#   'Dynamite',
#   '방탄소년단',
#   'Dynamite (DayTime Version)',
#   'https://music.bugs.co.kr/album/20344912?wl_ref=list_tr_11_chart'],
#  ['26',
#   'Bugs/Bugs26.jpg',
#   '새삥 (Prod. ZICO) (Feat. 호미들)',
#   '지코',
#   '스트릿 맨 파이터(SMF) Original Vol.3 (계급미션)',
#   'https://music.bugs.co.kr/album/20490588?wl_ref=list_tr_11_chart'],
#  ['27',
#   'Bugs/Bugs27.jpg',
#   'Pink Venom',
#   'BLACKPINK',
#   'BORN PINK',
#   'https://music.bugs.co.kr/album/4078880?wl_ref=list_tr_11_chart'],
#  ['28',
#   'Bugs/Bugs28.jpg',
#   'Monologue',
#   '테이(Tei)',
#   'Monologue',
#   'https://music.bugs.co.kr/album/4079823?wl_ref=list_tr_11_chart'],
#  ['29',
#   'Bugs/Bugs29.jpg',
#   '너의 모든 순간',
#   '성시경',
#   '별에서 온 그대 (SBS 수목드라마) OST - Part.7',
#   'https://music.bugs.co.kr/album/413209?wl_ref=list_tr_11_chart'],
#  ['30',
#   'Bugs/Bugs30.jpg',
#   'Made You Look',
#   'Meghan Trainor(메간 트레이너)',
#   "Takin' It Back",
#   'https://music.bugs.co.kr/album/19896475?wl_ref=list_tr_11_chart'],
#  ['31',
#   'Bugs/Bugs31.jpg',
#   'Butter',
#   '방탄소년단',
#   'Butter',
#   'https://music.bugs.co.kr/album/20398006?wl_ref=list_tr_11_chart'],
#  ['32',
#   'Bugs/Bugs32.jpg',
#   '사랑인가 봐',
#   '멜로망스(MeloMance)',
#   '사랑인가 봐 (사내맞선 OST 스페셜 트랙)',
#   'https://music.bugs.co.kr/album/4071363?wl_ref=list_tr_11_chart'],
#  ['33',
#   'Bugs/Bugs33.jpg',
#   'ELEVEN',
#   'IVE (아이브)',
#   'ELEVEN',
#   'https://music.bugs.co.kr/album/4068361?wl_ref=list_tr_11_chart'],
#  ['34',
#   'Bugs/Bugs34.jpg',
#   'TOMBOY',
#   '(여자)아이들',
#   'I NEVER DIE',
#   'https://music.bugs.co.kr/album/4072414?wl_ref=list_tr_11_chart'],
#  ['35',
#   'Bugs/Bugs35.jpg',
#   'Say I Love You',
#   '우디(Woody)',
#   'Say I Love You (Re : WIND 4MEN Vol.04)',
#   'https://music.bugs.co.kr/album/20535938?wl_ref=list_tr_11_chart'],
#  ['36',
#   'Bugs/Bugs36.jpg',
#   '친구로 지내다 보면 (Feat. 김민석 of 멜로망스)',
#   'BIG Naughty (서동현)',
#   '친구로 지내다 보면',
#   'https://music.bugs.co.kr/album/4083370?wl_ref=list_tr_11_chart'],
#  ['37',
#   'Bugs/Bugs37.jpg',
#   '한 페이지가 될 수 있게',
#   'DAY6 (데이식스)',
#   'The Book of Us : Gravity',
#   'https://music.bugs.co.kr/album/20265759?wl_ref=list_tr_11_chart'],
#  ['38',
#   'Bugs/Bugs38.jpg',
#   "That's Hilarious",
#   'Charlie Puth(찰리 푸스)',
#   "That's Hilarious",
#   'https://music.bugs.co.kr/album/17671399?wl_ref=list_tr_11_chart'],
#  ['39',
#   'Bugs/Bugs39.jpg',
#   'Ay-Yo',
#   'NCT 127',
#   'Ay-Yo - The 4th Album Repackage',
#   'https://music.bugs.co.kr/album/4083334?wl_ref=list_tr_11_chart'],
#  ['40',
#   'Bugs/Bugs40.jpg',
#   '그댄 행복에 살텐데 (2022)',
#   '최유리',
#   '그댄 행복에 살텐데 (2022)',
#   'https://music.bugs.co.kr/album/20536736?wl_ref=list_tr_11_chart'],
#  ['41',
#   'Bugs/Bugs41.jpg',
#   '그라데이션',
#   '10CM',
#   '5.3',
#   'https://music.bugs.co.kr/album/4077389?wl_ref=list_tr_11_chart'],
#  ['42',
#   'Bugs/Bugs42.jpg',
#   'Permission to Dance',
#   '방탄소년단',
#   'Butter / Permission to Dance',
#   'https://music.bugs.co.kr/album/4055320?wl_ref=list_tr_11_chart'],
#  ['43',
#   'Bugs/Bugs43.jpg',
#   '봄날',
#   '방탄소년단',
#   'YOU NEVER WALK ALONE',
#   'https://music.bugs.co.kr/album/20081605?wl_ref=list_tr_11_chart'],
#  ['44',
#   'Bugs/Bugs44.jpg',
#   'Dangerously',
#   'Charlie Puth(찰리 푸스)',
#   'Nine Track Mind (Deluxe Edition)',
#   'https://music.bugs.co.kr/album/527746?wl_ref=list_tr_11_chart'],
#  ['45',
#   'Bugs/Bugs45.jpg',
#   '마지막 사랑',
#   '신예영',
#   '마지막 사랑',
#   'https://music.bugs.co.kr/album/4083020?wl_ref=list_tr_11_chart'],
#  ['46',
#   'Bugs/Bugs46.jpg',
#   '자격지심 (Feat. ZICO)',
#   "BE'O (비오)",
#   'FIVE SENSES',
#   'https://music.bugs.co.kr/album/4080200?wl_ref=list_tr_11_chart'],
#  ['47',
#   'Bugs/Bugs47.jpg',
#   '해요 (2022)',
#   '#안녕',
#   '해요 (2022)',
#   'https://music.bugs.co.kr/album/20472041?wl_ref=list_tr_11_chart'],
#  ['48',
#   'Bugs/Bugs48.jpg',
#   'Yet To Come',
#   '방탄소년단',
#   'Proof',
#   'https://music.bugs.co.kr/album/20473078?wl_ref=list_tr_11_chart'],
#  ['49',
#   'Bugs/Bugs49.jpg',
#   'My Universe',
#   'Coldplay(콜드플레이)',
#   'My Universe',
#   'https://music.bugs.co.kr/album/16183960?wl_ref=list_tr_11_chart'],
#  ['50',
#   'Bugs/Bugs50.jpg',
#   'Hurt',
#   'NewJeans',
#   "NewJeans 1st EP 'New Jeans'",
#   'https://music.bugs.co.kr/album/4078016?wl_ref=list_tr_11_chart'],
#  ['51',
#   'Bugs/Bugs51.jpg',
#   'Christmas Tree',
#   'V',
#   '그 해 우리는 OST Part.5',
#   'https://music.bugs.co.kr/album/4069371?wl_ref=list_tr_11_chart'],
#  ['52',
#   'Bugs/Bugs52.jpg',
#   '다정히 내 이름을 부르면',
#   '경서예지',
#   '다정히 내 이름을 부르면 (경서예지 x 전건호)',
#   'https://music.bugs.co.kr/album/4045282?wl_ref=list_tr_11_chart'],
#  ['53',
#   'Bugs/Bugs53.jpg',
#   '정이라고 하자 (Feat. 10CM)',
#   'BIG Naughty (서동현)',
#   '정이라고 하자',
#   'https://music.bugs.co.kr/album/4074520?wl_ref=list_tr_11_chart'],
#  ['54',
#   'Bugs/Bugs54.jpg',
#   '그때 그 순간 그대로 (그그그)',
#   'WSG워너비 (가야G)',
#   'WSG워너비 1집',
#   'https://music.bugs.co.kr/album/4077595?wl_ref=list_tr_11_chart'],
#  ['55',
#   'Bugs/Bugs55.jpg',
#   '도깨비불 (Illusion)',
#   'aespa',
#   'Girls - The 2nd Mini Album',
#   'https://music.bugs.co.kr/album/20471520?wl_ref=list_tr_11_chart'],
#  ['56',
#   'Bugs/Bugs56.jpg',
#   'STAY',
#   'The Kid LAROI',
#   'STAY',
#   'https://music.bugs.co.kr/album/15817728?wl_ref=list_tr_11_chart'],
#  ['57',
#   'Bugs/Bugs57.jpg',
#   'When I Get Old',
#   'Christopher(크리스토퍼)',
#   'When I Get Old',
#   'https://music.bugs.co.kr/album/19918891?wl_ref=list_tr_11_chart'],
#  ['58',
#   'Bugs/Bugs58.jpg',
#   '달려라 방탄',
#   '방탄소년단',
#   'Proof',
#   'https://music.bugs.co.kr/album/20473078?wl_ref=list_tr_11_chart'],
#  ['59',
#   'Bugs/Bugs59.jpg',
#   '취중고백',
#   '김민석 (멜로망스)',
#   '취중고백',
#   'https://music.bugs.co.kr/album/4069154?wl_ref=list_tr_11_chart'],
#  ['60',
#   'Bugs/Bugs60.jpg',
#   '딱 10CM만',
#   '10CM',
#   '딱 10CM만',
#   'https://music.bugs.co.kr/album/4080055?wl_ref=list_tr_11_chart'],
#  ['61',
#   'Bugs/Bugs61.jpg',
#   '모든 날, 모든 순간 (Every day, Every Moment)',
#   '폴킴(Paul Kim)',
#   "'키스 먼저 할까요?' OST Part.3",
#   'https://music.bugs.co.kr/album/20154722?wl_ref=list_tr_11_chart'],
#  ['62',
#   'Bugs/Bugs62.jpg',
#   'INVU',
#   '태연 (TAEYEON)',
#   'INVU - The 3rd Album',
#   'https://music.bugs.co.kr/album/20450649?wl_ref=list_tr_11_chart'],
#  ['63',
#   'Bugs/Bugs63.jpg',
#   'Impurities',
#   'LE SSERAFIM (르세라핌)',
#   'ANTIFRAGILE',
#   'https://music.bugs.co.kr/album/4080706?wl_ref=list_tr_11_chart'],
#  ['64',
#   'Bugs/Bugs64.jpg',
#   'Anti-Hero',
#   'Taylor Swift(테일러 스위프트)',
#   'Midnights (3am Edition)',
#   'https://music.bugs.co.kr/album/19940060?wl_ref=list_tr_11_chart'],
#  ['65',
#   'Bugs/Bugs65.jpg',
#   'Off My Face',
#   'Justin Bieber(저스틴 비버)',
#   'Justice',
#   'https://music.bugs.co.kr/album/15175845?wl_ref=list_tr_11_chart'],
#  ['66',
#   'Bugs/Bugs66.jpg',
#   '들꽃놀이 (with 조유진)',
#   'RM',
#   'Indigo',
#   'https://music.bugs.co.kr/album/4081989?wl_ref=list_tr_11_chart'],
#  ['67',
#   'Bugs/Bugs67.jpg',
#   'Feel My Rhythm',
#   'Red Velvet (레드벨벳)',
#   '‘The ReVe Festival 2022 - Feel My Rhythm’',
#   'https://music.bugs.co.kr/album/20457046?wl_ref=list_tr_11_chart'],
#  ['68',
#   'Bugs/Bugs68.jpg',
#   'strawberry moon',
#   '아이유(IU)',
#   'strawberry moon',
#   'https://music.bugs.co.kr/album/4066238?wl_ref=list_tr_11_chart'],
#  ['69',
#   'Bugs/Bugs69.jpg',
#   '그대를 알고',
#   '송하예',
#   '그대를 알고',
#   'https://music.bugs.co.kr/album/4082235?wl_ref=list_tr_11_chart'],
#  ['70',
#   'Bugs/Bugs70.jpg',
#   '나의 X에게',
#   '경서',
#   '나의 X에게',
#   'https://music.bugs.co.kr/album/4074701?wl_ref=list_tr_11_chart'],
#  ['71',
#   'Bugs/Bugs71.jpg',
#   '봄여름가을겨울 (Still Life)',
#   'BIGBANG (빅뱅)',
#   '봄여름가을겨울 (Still Life)',
#   'https://music.bugs.co.kr/album/4073653?wl_ref=list_tr_11_chart'],
#  ['72',
#   'Bugs/Bugs72.jpg',
#   '우린 그렇게 사랑해서',
#   '강민경',
#   '우린 그렇게 사랑해서',
#   'https://music.bugs.co.kr/album/20495162?wl_ref=list_tr_11_chart'],
#  ['73',
#   'Bugs/Bugs73.jpg',
#   'Life Goes On',
#   '방탄소년단',
#   'BE',
#   'https://music.bugs.co.kr/album/20361943?wl_ref=list_tr_11_chart'],
#  ['74',
#   'Bugs/Bugs74.jpg',
#   '내가 아니라도',
#   '주호',
#   '내가 아니라도',
#   'https://music.bugs.co.kr/album/4073229?wl_ref=list_tr_11_chart'],
#  ['75',
#   'Bugs/Bugs75.jpg',
#   'Sugar Rush Ride',
#   '투모로우바이투게더',
#   '이름의 장: TEMPTATION',
#   'https://music.bugs.co.kr/album/4083345?wl_ref=list_tr_11_chart'],
#  ['76',
#   'Bugs/Bugs76.jpg',
#   '사랑은 늘 도망가',
#   '임영웅',
#   '신사와 아가씨 OST Part.2',
#   'https://music.bugs.co.kr/album/4065831?wl_ref=list_tr_11_chart'],
#  ['77',
#   'Bugs/Bugs77.jpg',
#   'LOVE me',
#   "BE'O (비오)",
#   'LOVE me',
#   'https://music.bugs.co.kr/album/4074098?wl_ref=list_tr_11_chart'],
#  ['78',
#   'Bugs/Bugs78.jpg',
#   'STEP',
#   '카라(Kara)',
#   'KARA 3rd Album STEP',
#   'https://music.bugs.co.kr/album/298546?wl_ref=list_tr_11_chart'],
#  ['79',
#   'Bugs/Bugs79.jpg',
#   '주저하는 연인들을 위해',
#   '잔나비',
#   '전설',
#   'https://music.bugs.co.kr/album/20237198?wl_ref=list_tr_11_chart'],
#  ['80',
#   'Bugs/Bugs80.jpg',
#   'The Astronaut',
#   '진(Jin)',
#   'The Astronaut',
#   'https://music.bugs.co.kr/album/4081084?wl_ref=list_tr_11_chart'],
#  ['81',
#   'Bugs/Bugs81.jpg',
#   '드라마',
#   '아이유(IU)',
#   '조각집',
#   'https://music.bugs.co.kr/album/4069567?wl_ref=list_tr_11_chart'],
#  ['82',
#   'Bugs/Bugs82.jpg',
#   '보고싶었어',
#   'WSG워너비(4FIRE)',
#   'WSG워너비 1집',
#   'https://music.bugs.co.kr/album/4077595?wl_ref=list_tr_11_chart'],
#  ['83',
#   'Bugs/Bugs83.jpg',
#   '잘가요',
#   '주호',
#   '잘가요',
#   'https://music.bugs.co.kr/album/4082024?wl_ref=list_tr_11_chart'],
#  ['84',
#   'Bugs/Bugs84.jpg',
#   'Next Level',
#   'aespa',
#   'Next Level',
#   'https://music.bugs.co.kr/album/20397321?wl_ref=list_tr_11_chart'],
#  ['85',
#   'Bugs/Bugs85.jpg',
#   'Love story',
#   '볼빨간사춘기',
#   'Seoul',
#   'https://music.bugs.co.kr/album/4074262?wl_ref=list_tr_11_chart'],
#  ['86',
#   'Bugs/Bugs86.jpg',
#   '아픈 나를 (Prod. By 나얼)',
#   '성시경',
#   '나얼 <Ballad Pop City>',
#   'https://music.bugs.co.kr/album/4082656?wl_ref=list_tr_11_chart'],
#  ['87',
#   'Bugs/Bugs87.jpg',
#   '떠나보낼 준비해 둘걸 그랬어',
#   '임한별',
#   '떠나보낼 준비해 둘걸 그랬어',
#   'https://music.bugs.co.kr/album/4080735?wl_ref=list_tr_11_chart'],
#  ['88',
#   'Bugs/Bugs88.jpg',
#   'Snowman',
#   'Sia(시아)',
#   'Everyday Is Christmas (Snowman Deluxe Edition)',
#   'https://music.bugs.co.kr/album/680332?wl_ref=list_tr_11_chart'],
#  ['89',
#   'Bugs/Bugs89.jpg',
#   '팡파레',
#   '다비치',
#   'Season Note',
#   'https://music.bugs.co.kr/album/20468120?wl_ref=list_tr_11_chart'],
#  ['90',
#   'Bugs/Bugs90.jpg',
#   'FOREVER 1',
#   "소녀시대 (GIRLS' GENERATION)",
#   'FOREVER 1 - The 7th Album',
#   'https://music.bugs.co.kr/album/20484595?wl_ref=list_tr_11_chart'],
#  ['91',
#   'Bugs/Bugs91.jpg',
#   'Talk that Talk',
#   'TWICE (트와이스)',
#   'BETWEEN 1&2',
#   'https://music.bugs.co.kr/album/20488834?wl_ref=list_tr_11_chart'],
#  ['92',
#   'Bugs/Bugs92.jpg',
#   "I Ain't Worried",
#   'OneRepublic(원리퍼블릭)',
#   '탑건 : 매버릭 (Top Gun: Maverick) (영화 OST)',
#   'https://music.bugs.co.kr/album/18047275?wl_ref=list_tr_11_chart'],
#  ['93',
#   'Bugs/Bugs93.jpg',
#   '사랑해도 될까요',
#   '양다일',
#   '사랑해도 될까요',
#   'https://music.bugs.co.kr/album/4083088?wl_ref=list_tr_11_chart'],
#  ['94',
#   'Bugs/Bugs94.jpg',
#   '눈이 오잖아(Feat.헤이즈)',
#   '이무진',
#   '눈이 오잖아(Feat.헤이즈)',
#   'https://music.bugs.co.kr/album/4068421?wl_ref=list_tr_11_chart'],
#  ['95',
#   'Bugs/Bugs95.jpg',
#   '신호등',
#   '이무진',
#   '신호등',
#   'https://music.bugs.co.kr/album/4044879?wl_ref=list_tr_11_chart'],
#  ['96',
#   'Bugs/Bugs96.jpg',
#   'DICE',
#   'NMIXX',
#   'ENTWURF',
#   'https://music.bugs.co.kr/album/20493467?wl_ref=list_tr_11_chart'],
#  ['97',
#   'Bugs/Bugs97.jpg',
#   'Beautiful Liar',
#   '몬스타엑스(Monsta X)',
#   'REASON',
#   'https://music.bugs.co.kr/album/4082924?wl_ref=list_tr_11_chart'],
#  ['98',
#   'Bugs/Bugs98.jpg',
#   '니 번호가 뜨는 일',
#   '이예준',
#   '니 번호가 뜨는 일',
#   'https://music.bugs.co.kr/album/4083125?wl_ref=list_tr_11_chart'],
#  ['99',
#   'Bugs/Bugs99.jpg',
#   'Love War (Feat. BE‘O)',
#   'YENA (최예나)',
#   'Love War',
#   'https://music.bugs.co.kr/album/20540146?wl_ref=list_tr_11_chart'],
#  ['100',
#   'Bugs/Bugs100.jpg',
#   '마이웨이 (MY WAY) (Prod. R.Tee)',
#   '저스디스(JUSTHIS)',
#   '쇼미더머니 11 Episode 1',
#   'https://music.bugs.co.kr/album/20531482?wl_ref=list_tr_11_chart']]

# %%
import requests
from bs4 import BeautifulSoup
import json
import os
os.environ.setdefault("DJANGO_SETTINGS_MODULE", "config.settings")

import django
django.setup()

from music.models import BugsWeekTop

def parse_music():
  header = {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/39.0.2171.95 Safari/537.36'}
  req = requests.get('https://music.bugs.co.kr/chart/track/week/total',headers = header)

  # 1차 크롤링
  soup = BeautifulSoup(req.content,'html.parser')
  bugscharts = soup.select('#CHARTweek > table > tbody > tr')
  
  data = []
  # data = {}
  for idx, bugschart in enumerate(bugscharts):
    # 순위
    rank = bugschart.select('td > div.ranking > strong')[0].text
    # 앨범표지
    image = 'Bugs/Bugs{}.jpg'.format((idx+1))
    # 가수
    title = bugschart.select('th > p.title > a')[0].text
    # 곡 제목 찾기
    musician = bugschart.select('td > p.artist > a')[0].text
    # 앨범
    album = bugschart.select('td > a.album')[0].text
    # 앨범 detail 정보
    album_link = bugschart.select_one('td > a.album').attrs['href']

    
    req1 = requests.get(album_link,headers = header)

    # 2차 크롤링
    soup1 = BeautifulSoup(req1.content,'html.parser')
    album_info = soup1.select("#container > section.sectionPadding.summaryInfo.summaryAlbum > div > div.basicInfo > table > tbody")
    # released_at = album_info.select("tr:nth-child(3) > td > time")[0].text
    # genre = album_info.select('tr:nth-child(4) > td > a')[0].text
    # released_cop = album_info.select('tr:nth-child(7) > td')[0].text
    # planned_cop = album_info.select('tr:nth-child(6) > td')[0].text
    for album_info in album_info:
        # tr:nth-child(3) > td > time 발매일
        # tr:nth-child(4) > td > a 장르
        # 기획사 tr:nth-child(6) > td
        # 발매사 tr:nth-child(7) > td
        released_at = album_info.select("tr:nth-child(3) > td > time")[0].text
        genre = album_info.select('tr:nth-child(4) > td > a')[0].text
        released_cop = album_info.select('tr:nth-child(7) > td')[0].text
        planned_cop = album_info.select('tr:nth-child(6) > td')[0].text

        # 2차 크롤링 추가
        
    data.append([rank,image,title,musician,album,released_at,genre,released_cop,planned_cop])
  
  return data 

parse_music()
# Out:
# [['1',
#   'Bugs/Bugs1.jpg',
#   'Ditto',
#   'NewJeans',
#   "NewJeans 'OMG'",
#   '2023.01.02',
#   '댄스/팝',
#   'YG PLUS',
#   'ADOR'],
#  ['2',
#   'Bugs/Bugs2.jpg',
#   'OMG',
#   'NewJeans',
#   "NewJeans 'OMG'",
#   '2023.01.02',
#   '댄스/팝',
#   'YG PLUS',
#   'ADOR'],
#  ['3',
#   'Bugs/Bugs3.jpg',
#   'Hype Boy',
#   'NewJeans',
#   "NewJeans 1st EP 'New Jeans'",
#   '2022.08.01',
#   '댄스/팝',
#   'YG PLUS',
#   'ADOR'],
#  ['4',
#   'Bugs/Bugs4.jpg',
#   'VIBE (feat. Jimin of BTS)',
#   '태양',
#   'VIBE (feat. Jimin of BTS)',
#   '2023.01.13',
#   '댄스/팝',
#   'YG PLUS',
#   'THEBLACKLABEL'],
#  ['5',
#   'Bugs/Bugs5.jpg',
#   'Attention',
#   'NewJeans',
#   "NewJeans 1st EP 'New Jeans'",
#   '2022.08.01',
#   '댄스/팝',
#   'YG PLUS',
#   'ADOR'],
#  ['6',
#   'Bugs/Bugs6.jpg',
#   '사건의 지평선',
#   '윤하(Younha/ユンナ)',
#   "YOUNHA 6th Album Repackage 'END THEORY : Final Edition'",
#   '2022.03.30',
#   '댄스/팝',
#   '카카오엔터테인먼트',
#   'C9 Entertainment'],
#  ['7',
#   'Bugs/Bugs7.jpg',
#   'ANTIFRAGILE',
#   'LE SSERAFIM (르세라핌)',
#   'ANTIFRAGILE',
#   '2022.10.17',
#   '댄스/팝',
#   'YG PLUS',
#   '쏘스뮤직'],
#  ['8',
#   'Bugs/Bugs8.jpg',
#   'After LIKE',
#   'IVE (아이브)',
#   'After LIKE',
#   '2022.08.22',
#   '댄스/팝',
#   '카카오엔터테인먼트',
#   '스타쉽엔터테인먼트'],
#  ['9',
#   'Bugs/Bugs9.jpg',
#   'Candy',
#   'NCT DREAM',
#   'Candy - Winter Special Mini Album',
#   '2022.12.16',
#   '댄스/팝',
#   'Dreamus',
#   'SM ENTERTAINMENT'],
#  ['10',
#   'Bugs/Bugs10.jpg',
#   'Rush Hour (Feat. j-hope of BTS)',
#   'Crush',
#   'Rush Hour',
#   '2022.09.22',
#   '알앤비/소울',
#   'Dreamus',
#   '피네이션'],
#  ['11',
#   'Bugs/Bugs11.jpg',
#   'I Don’t Think That I Like Her',
#   'Charlie Puth(찰리 푸스)',
#   'I Don’t Think That I Like Her',
#   '2022.09.16',
#   '팝',
#   '워너뮤직코리아',
#   'Atlantic Records'],
#  ['12',
#   'Bugs/Bugs12.jpg',
#   'Dreamers [Music from the FIFA World Cup Qatar 2022 Official Soundtrack] (feat. FIFA Sound)',
#   '정국',
#   'Dreamers [Music from the FIFA World Cup Qatar 2022 Official Soundtrack]',
#   '2022.11.20',
#   '팝',
#   'FUGA',
#   'Katara Studios | 2101 Records under exclusive license to UnitedMasters LLC'],
#  ['13',
#   'Bugs/Bugs13.jpg',
#   'LOVE DIVE',
#   'IVE (아이브)',
#   'LOVE DIVE',
#   '2022.04.05',
#   '댄스/팝',
#   '카카오엔터테인먼트',
#   '스타쉽엔터테인먼트'],
#  ['14',
#   'Bugs/Bugs14.jpg',
#   'Cookie',
#   'NewJeans',
#   "NewJeans 1st EP 'New Jeans'",
#   '2022.08.01',
#   '댄스/팝',
#   'YG PLUS',
#   'ADOR'],
#  ['15',
#   'Bugs/Bugs15.jpg',
#   '오르트구름',
#   '윤하(Younha/ユンナ)',
#   "YOUNHA 6th Album 'END THEORY'",
#   '2021.11.16',
#   '발라드',
#   '카카오엔터테인먼트',
#   'C9 Entertainment'],
#  ['16',
#   'Bugs/Bugs16.jpg',
#   'Unholy',
#   'Sam Smith(샘 스미스)',
#   'Unholy',
#   '2022.09.22',
#   '팝',
#   '유니버설뮤직코리아',
#   'EMI'],
#  ['17',
#   'Bugs/Bugs17.jpg',
#   'Left and Right (Feat. Jung Kook of BTS)',
#   'Charlie Puth(찰리 푸스)',
#   'Left and Right (Feat. Jung Kook of BTS)',
#   '2022.06.24',
#   '팝',
#   '워너뮤직코리아',
#   'Atlantic Records'],
#  ['18',
#   'Bugs/Bugs18.jpg',
#   'WHEN I MOVE',
#   '카라(Kara)',
#   'MOVE AGAIN',
#   '2022.11.29',
#   '댄스/팝',
#   'Dreamus',
#   '㈜RBW'],
#  ['19',
#   'Bugs/Bugs19.jpg',
#   'Nxde',
#   '(여자)아이들',
#   'I love',
#   '2022.10.17',
#   '댄스/팝',
#   '카카오엔터테인먼트',
#   '큐브 엔터테인먼트'],
#  ['20',
#   'Bugs/Bugs20.jpg',
#   'NOT SORRY (Feat. pH-1) (Prod. by Slom)',
#   '이영지',
#   '쇼미더머니 11 Episode 3',
#   '2022.12.17',
#   '랩/힙합',
#   '지니뮤직',
#   'Stone Music Entertainment'],
#  ['21',
#   'Bugs/Bugs21.jpg',
#   'Shut Down',
#   'BLACKPINK',
#   'BORN PINK',
#   '2022.09.16',
#   '댄스/팝',
#   'YG PLUS',
#   'YG Entertainment'],
#  ['22',
#   'Bugs/Bugs22.jpg',
#   'FEARLESS',
#   'LE SSERAFIM (르세라핌)',
#   'FEARLESS',
#   '2022.05.02',
#   '댄스/팝',
#   'YG PLUS',
#   '쏘스뮤직'],
#  ['23',
#   'Bugs/Bugs23.jpg',
#   '혼자서 걸어요 (Prod. by 나얼)',
#   '태연 (TAEYEON)',
#   '나얼 <Ballad Pop City>',
#   '2023.02.02',
#   '발라드',
#   '카카오엔터테인먼트',
#   '롱플레이뮤직'],
#  ['24',
#   'Bugs/Bugs24.jpg',
#   'That That (prod. & feat. SUGA of BTS)',
#   '싸이 (PSY)',
#   '싸다9',
#   '2022.04.29',
#   '댄스/팝',
#   'Dreamus',
#   'P NATION'],
#  ['25',
#   'Bugs/Bugs25.jpg',
#   'Dynamite',
#   '방탄소년단',
#   'Dynamite (DayTime Version)',
#   '2020.08.21',
#   '댄스/팝',
#   'YG PLUS',
#   'BIGHIT MUSIC'],
#  ['26',
#   'Bugs/Bugs26.jpg',
#   '새삥 (Prod. ZICO) (Feat. 호미들)',
#   '지코',
#   '스트릿 맨 파이터(SMF) Original Vol.3 (계급미션)',
#   '2022.09.06',
#   '랩/힙합',
#   '지니뮤직',
#   'Stone Music Entertainment'],
#  ['27',
#   'Bugs/Bugs27.jpg',
#   'Pink Venom',
#   'BLACKPINK',
#   'BORN PINK',
#   '2022.09.16',
#   '댄스/팝',
#   'YG PLUS',
#   'YG Entertainment'],
#  ['28',
#   'Bugs/Bugs28.jpg',
#   'Monologue',
#   '테이(Tei)',
#   'Monologue',
#   '2022.09.18',
#   '발라드',
#   '카카오엔터테인먼트',
#   '방구석캐스팅'],
#  ['29',
#   'Bugs/Bugs29.jpg',
#   '너의 모든 순간',
#   '성시경',
#   '별에서 온 그대 (SBS 수목드라마) OST - Part.7',
#   '2014.02.12',
#   '발라드',
#   'NHN벅스',
#   'SBS콘텐츠허브'],
#  ['30',
#   'Bugs/Bugs30.jpg',
#   'Made You Look',
#   'Meghan Trainor(메간 트레이너)',
#   "Takin' It Back",
#   '2022.10.21',
#   '팝',
#   'Sony Music',
#   'Epic'],
#  ['31',
#   'Bugs/Bugs31.jpg',
#   'Butter',
#   '방탄소년단',
#   'Butter',
#   '2021.05.21',
#   '댄스/팝',
#   'YG PLUS',
#   'BIGHIT MUSIC'],
#  ['32',
#   'Bugs/Bugs32.jpg',
#   '사랑인가 봐',
#   '멜로망스(MeloMance)',
#   '사랑인가 봐 (사내맞선 OST 스페셜 트랙)',
#   '2022.02.18',
#   '댄스/팝',
#   '카카오엔터테인먼트',
#   '플렉스엠'],
#  ['33',
#   'Bugs/Bugs33.jpg',
#   'ELEVEN',
#   'IVE (아이브)',
#   'ELEVEN',
#   '2021.12.01',
#   '댄스/팝',
#   '카카오엔터테인먼트',
#   '스타쉽엔터테인먼트'],
#  ['34',
#   'Bugs/Bugs34.jpg',
#   'TOMBOY',
#   '(여자)아이들',
#   'I NEVER DIE',
#   '2022.03.14',
#   '댄스/팝',
#   '카카오엔터테인먼트',
#   '큐브 엔터테인먼트'],
#  ['35',
#   'Bugs/Bugs35.jpg',
#   'Say I Love You',
#   '우디(Woody)',
#   'Say I Love You (Re : WIND 4MEN Vol.04)',
#   '2022.12.21',
#   '발라드',
#   '지니뮤직',
#   '메이저나인'],
#  ['36',
#   'Bugs/Bugs36.jpg',
#   '친구로 지내다 보면 (Feat. 김민석 of 멜로망스)',
#   'BIG Naughty (서동현)',
#   '친구로 지내다 보면',
#   '2023.01.29',
#   '인디',
#   '카카오엔터테인먼트',
#   'H1GHR MUSIC RECORDS'],
#  ['37',
#   'Bugs/Bugs37.jpg',
#   '한 페이지가 될 수 있게',
#   'DAY6 (데이식스)',
#   'The Book of Us : Gravity',
#   '2019.07.15',
#   '댄스/팝',
#   'Dreamus',
#   'JYP엔터테인먼트'],
#  ['38',
#   'Bugs/Bugs38.jpg',
#   "That's Hilarious",
#   'Charlie Puth(찰리 푸스)',
#   "That's Hilarious",
#   '2022.04.08',
#   '팝',
#   '워너뮤직코리아',
#   'Atlantic Records'],
#  ['39',
#   'Bugs/Bugs39.jpg',
#   'Ay-Yo',
#   'NCT 127',
#   'Ay-Yo - The 4th Album Repackage',
#   '2023.01.30',
#   '댄스/팝',
#   'Dreamus',
#   'SM ENTERTAINMENT'],
#  ['40',
#   'Bugs/Bugs40.jpg',
#   '그댄 행복에 살텐데 (2022)',
#   '최유리',
#   '그댄 행복에 살텐데 (2022)',
#   '2022.12.27',
#   '인디',
#   'Dreamus',
#   '일팔 프로젝트'],
#  ['41',
#   'Bugs/Bugs41.jpg',
#   '그라데이션',
#   '10CM',
#   '5.3',
#   '2022.07.03',
#   '인디',
#   '카카오엔터테인먼트',
#   '매직스트로베리 사운드'],
#  ['42',
#   'Bugs/Bugs42.jpg',
#   'Permission to Dance',
#   '방탄소년단',
#   'Butter / Permission to Dance',
#   '2021.07.09',
#   '댄스/팝',
#   'YG PLUS',
#   'BIGHIT MUSIC'],
#  ['43',
#   'Bugs/Bugs43.jpg',
#   '봄날',
#   '방탄소년단',
#   'YOU NEVER WALK ALONE',
#   '2017.02.13',
#   '댄스/팝',
#   'YG PLUS',
#   'BIGHIT MUSIC'],
#  ['44',
#   'Bugs/Bugs44.jpg',
#   'Dangerously',
#   'Charlie Puth(찰리 푸스)',
#   'Nine Track Mind (Deluxe Edition)',
#   '2016.11.11',
#   '팝',
#   '워너뮤직코리아',
#   'Artist Partner'],
#  ['45',
#   'Bugs/Bugs45.jpg',
#   '마지막 사랑',
#   '신예영',
#   '마지막 사랑',
#   '2023.01.12',
#   '발라드',
#   '카카오엔터테인먼트',
#   '투플원엔터테인먼트, (주)제나두엔터테인먼트'],
#  ['46',
#   'Bugs/Bugs46.jpg',
#   '자격지심 (Feat. ZICO)',
#   "BE'O (비오)",
#   'FIVE SENSES',
#   '2022.09.29',
#   '댄스/팝',
#   '카카오엔터테인먼트',
#   '빅플래닛메이드, SWING ENTERTAINMENT, 페임어스 엔터테인먼트'],
#  ['47',
#   'Bugs/Bugs47.jpg',
#   '해요 (2022)',
#   '#안녕',
#   '해요 (2022)',
#   '2022.06.07',
#   '발라드',
#   '지니뮤직',
#   '일팔 프로젝트'],
#  ['48',
#   'Bugs/Bugs48.jpg',
#   'Yet To Come',
#   '방탄소년단',
#   'Proof',
#   '2022.06.10',
#   '댄스/팝',
#   'YG PLUS',
#   'BIGHIT MUSIC'],
#  ['49',
#   'Bugs/Bugs49.jpg',
#   'My Universe',
#   'Coldplay(콜드플레이)',
#   'My Universe',
#   '2021.09.24',
#   '팝',
#   '워너뮤직코리아',
#   'Parlophone UK'],
#  ['50',
#   'Bugs/Bugs50.jpg',
#   'Hurt',
#   'NewJeans',
#   "NewJeans 1st EP 'New Jeans'",
#   '2022.08.01',
#   '댄스/팝',
#   'YG PLUS',
#   'ADOR'],
#  ['51',
#   'Bugs/Bugs51.jpg',
#   'Christmas Tree',
#   'V',
#   '그 해 우리는 OST Part.5',
#   '2021.12.24',
#   '발라드',
#   'NHN벅스',
#   '모스트콘텐츠'],
#  ['52',
#   'Bugs/Bugs52.jpg',
#   '다정히 내 이름을 부르면',
#   '경서예지',
#   '다정히 내 이름을 부르면 (경서예지 x 전건호)',
#   '2021.05.19',
#   '발라드',
#   '카카오엔터테인먼트',
#   '에버그로우'],
#  ['53',
#   'Bugs/Bugs53.jpg',
#   '정이라고 하자 (Feat. 10CM)',
#   'BIG Naughty (서동현)',
#   '정이라고 하자',
#   '2022.04.20',
#   '인디',
#   '카카오엔터테인먼트',
#   'H1GHR MUSIC RECORDS'],
#  ['54',
#   'Bugs/Bugs54.jpg',
#   '그때 그 순간 그대로 (그그그)',
#   'WSG워너비 (가야G)',
#   'WSG워너비 1집',
#   '2022.07.09',
#   '댄스/팝',
#   '카카오엔터테인먼트',
#   '문화방송'],
#  ['55',
#   'Bugs/Bugs55.jpg',
#   '도깨비불 (Illusion)',
#   'aespa',
#   'Girls - The 2nd Mini Album',
#   '2022.07.08',
#   '댄스/팝',
#   'Dreamus',
#   'SM ENTERTAINMENT'],
#  ['56',
#   'Bugs/Bugs56.jpg',
#   'STAY',
#   'The Kid LAROI',
#   'STAY',
#   '2021.07.09',
#   '팝',
#   'Sony Music',
#   'Columbia'],
#  ['57',
#   'Bugs/Bugs57.jpg',
#   'When I Get Old',
#   'Christopher(크리스토퍼)',
#   'When I Get Old',
#   '2022.10.20',
#   '팝',
#   '워너뮤직코리아',
#   'Parlophone Denmark'],
#  ['58',
#   'Bugs/Bugs58.jpg',
#   '달려라 방탄',
#   '방탄소년단',
#   'Proof',
#   '2022.06.10',
#   '댄스/팝',
#   'YG PLUS',
#   'BIGHIT MUSIC'],
#  ['59',
#   'Bugs/Bugs59.jpg',
#   '취중고백',
#   '김민석 (멜로망스)',
#   '취중고백',
#   '2021.12.19',
#   '발라드',
#   '워너뮤직코리아',
#   '프로젝트 리본'],
#  ['60',
#   'Bugs/Bugs60.jpg',
#   '딱 10CM만',
#   '10CM',
#   '딱 10CM만',
#   '2022.09.25',
#   '알앤비/소울',
#   '카카오엔터테인먼트',
#   'MAGIC STRAWBERRY SOUND, H1GHR MUSIC RECORDS'],
#  ['61',
#   'Bugs/Bugs61.jpg',
#   '모든 날, 모든 순간 (Every day, Every Moment)',
#   '폴킴(Paul Kim)',
#   "'키스 먼저 할까요?' OST Part.3",
#   '2018.03.20',
#   '발라드',
#   'Dreamus',
#   'SM ENTERTAINMENT'],
#  ['62',
#   'Bugs/Bugs62.jpg',
#   'INVU',
#   '태연 (TAEYEON)',
#   'INVU - The 3rd Album',
#   '2022.02.14',
#   '댄스/팝',
#   'Dreamus',
#   'SM ENTERTAINMENT'],
#  ['63',
#   'Bugs/Bugs63.jpg',
#   'Impurities',
#   'LE SSERAFIM (르세라핌)',
#   'ANTIFRAGILE',
#   '2022.10.17',
#   '댄스/팝',
#   'YG PLUS',
#   '쏘스뮤직'],
#  ['64',
#   'Bugs/Bugs64.jpg',
#   'Anti-Hero',
#   'Taylor Swift(테일러 스위프트)',
#   'Midnights (3am Edition)',
#   '2022.10.21',
#   '팝',
#   '유니버설뮤직코리아',
#   'Taylor Swift'],
#  ['65',
#   'Bugs/Bugs65.jpg',
#   'Off My Face',
#   'Justin Bieber(저스틴 비버)',
#   'Justice',
#   '2021.03.19',
#   '팝',
#   '유니버설뮤직코리아',
#   'RBMG, Def Jam Recordings'],
#  ['66',
#   'Bugs/Bugs66.jpg',
#   '들꽃놀이 (with 조유진)',
#   'RM',
#   'Indigo',
#   '2022.12.02',
#   '일렉트로닉',
#   'YG PLUS',
#   'BIGHIT MUSIC'],
#  ['67',
#   'Bugs/Bugs67.jpg',
#   'Feel My Rhythm',
#   'Red Velvet (레드벨벳)',
#   '‘The ReVe Festival 2022 - Feel My Rhythm’',
#   '2022.03.21',
#   '댄스/팝',
#   'Dreamus',
#   'SM ENTERTAINMENT'],
#  ['68',
#   'Bugs/Bugs68.jpg',
#   'strawberry moon',
#   '아이유(IU)',
#   'strawberry moon',
#   '2021.10.19',
#   '댄스/팝',
#   '카카오엔터테인먼트',
#   'EDAM엔터테인먼트'],
#  ['69',
#   'Bugs/Bugs69.jpg',
#   '그대를 알고',
#   '송하예',
#   '그대를 알고',
#   '2022.12.13',
#   '인디',
#   '카카오엔터테인먼트',
#   '디스튜디오'],
#  ['70',
#   'Bugs/Bugs70.jpg',
#   '나의 X에게',
#   '경서',
#   '나의 X에게',
#   '2022.04.24',
#   '인디',
#   '카카오엔터테인먼트',
#   '꿈의엔진'],
#  ['71',
#   'Bugs/Bugs71.jpg',
#   '봄여름가을겨울 (Still Life)',
#   'BIGBANG (빅뱅)',
#   '봄여름가을겨울 (Still Life)',
#   '2022.04.05',
#   '댄스/팝',
#   'YG PLUS',
#   'YG Entertainment'],
#  ['72',
#   'Bugs/Bugs72.jpg',
#   '우린 그렇게 사랑해서',
#   '강민경',
#   '우린 그렇게 사랑해서',
#   '2022.09.26',
#   '발라드',
#   '지니뮤직, Stone Music Entertainment',
#   'WAKEONE, 페포니뮤직'],
#  ['73',
#   'Bugs/Bugs73.jpg',
#   'Life Goes On',
#   '방탄소년단',
#   'BE',
#   '2020.11.20',
#   '댄스/팝',
#   'YG PLUS',
#   'BIGHIT MUSIC'],
#  ['74',
#   'Bugs/Bugs74.jpg',
#   '내가 아니라도',
#   '주호',
#   '내가 아니라도',
#   '2022.03.25',
#   '발라드',
#   '워너뮤직코리아',
#   'IN A MILLION'],
#  ['75',
#   'Bugs/Bugs75.jpg',
#   'Sugar Rush Ride',
#   '투모로우바이투게더',
#   '이름의 장: TEMPTATION',
#   '2023.01.27',
#   '댄스/팝',
#   'YG PLUS',
#   'BIGHIT MUSIC'],
#  ['76',
#   'Bugs/Bugs76.jpg',
#   '사랑은 늘 도망가',
#   '임영웅',
#   '신사와 아가씨 OST Part.2',
#   '2021.10.11',
#   '발라드',
#   'NHN벅스',
#   '모스트콘텐츠'],
#  ['77',
#   'Bugs/Bugs77.jpg',
#   'LOVE me',
#   "BE'O (비오)",
#   'LOVE me',
#   '2022.04.12',
#   '랩/힙합',
#   '카카오엔터테인먼트',
#   'BPM ENTERTAINMENT, SWING ENTERTAINMENT, 페임어스 엔터테인먼트'],
#  ['78',
#   'Bugs/Bugs78.jpg',
#   'STEP',
#   '카라(Kara)',
#   'KARA 3rd Album STEP',
#   '2011.09.06',
#   '댄스/팝',
#   '카카오엔터테인먼트',
#   'DSP미디어'],
#  ['79',
#   'Bugs/Bugs79.jpg',
#   '주저하는 연인들을 위해',
#   '잔나비',
#   '전설',
#   '2019.03.13',
#   '인디',
#   '카카오엔터테인먼트',
#   '페포니 뮤직'],
#  ['80',
#   'Bugs/Bugs80.jpg',
#   'The Astronaut',
#   '진(Jin)',
#   'The Astronaut',
#   '2022.10.28',
#   '락/메탈',
#   'YG PLUS',
#   'BIGHIT MUSIC'],
#  ['81',
#   'Bugs/Bugs81.jpg',
#   '드라마',
#   '아이유(IU)',
#   '조각집',
#   '2021.12.29',
#   '포크/어쿠스틱',
#   '카카오엔터테인먼트',
#   'EDAM엔터테인먼트'],
#  ['82',
#   'Bugs/Bugs82.jpg',
#   '보고싶었어',
#   'WSG워너비(4FIRE)',
#   'WSG워너비 1집',
#   '2022.07.09',
#   '댄스/팝',
#   '카카오엔터테인먼트',
#   '문화방송'],
#  ['83',
#   'Bugs/Bugs83.jpg',
#   '잘가요',
#   '주호',
#   '잘가요',
#   '2022.12.04',
#   '발라드',
#   '워너뮤직코리아',
#   '레이벡스'],
#  ['84',
#   'Bugs/Bugs84.jpg',
#   'Next Level',
#   'aespa',
#   'Next Level',
#   '2021.05.17',
#   '댄스/팝',
#   'Dreamus',
#   'SM ENTERTAINMENT'],
#  ['85',
#   'Bugs/Bugs85.jpg',
#   'Love story',
#   '볼빨간사춘기',
#   'Seoul',
#   '2022.04.20',
#   '인디',
#   'NHN벅스',
#   '쇼파르엔터테인먼트'],
#  ['86',
#   'Bugs/Bugs86.jpg',
#   '아픈 나를 (Prod. By 나얼)',
#   '성시경',
#   '나얼 <Ballad Pop City>',
#   '2022.12.27',
#   '발라드',
#   '카카오엔터테인먼트',
#   '롱플레이뮤직'],
#  ['87',
#   'Bugs/Bugs87.jpg',
#   '떠나보낼 준비해 둘걸 그랬어',
#   '임한별',
#   '떠나보낼 준비해 둘걸 그랬어',
#   '2022.10.18',
#   '발라드',
#   '카카오엔터테인먼트',
#   '오늘의 선곡'],
#  ['88',
#   'Bugs/Bugs88.jpg',
#   'Snowman',
#   'Sia(시아)',
#   'Everyday Is Christmas (Snowman Deluxe Edition)',
#   '2022.12.30',
#   '캐롤',
#   '워너뮤직코리아',
#   'Monkey Puzzle/Atlantic'],
#  ['89',
#   'Bugs/Bugs89.jpg',
#   '팡파레',
#   '다비치',
#   'Season Note',
#   '2022.05.16',
#   '발라드',
#   '지니뮤직, Stone Music Entertainment',
#   'WAKEONE'],
#  ['90',
#   'Bugs/Bugs90.jpg',
#   'FOREVER 1',
#   "소녀시대 (GIRLS' GENERATION)",
#   'FOREVER 1 - The 7th Album',
#   '2022.08.05',
#   '댄스/팝',
#   'Dreamus',
#   'SM ENTERTAINMENT'],
#  ['91',
#   'Bugs/Bugs91.jpg',
#   'Talk that Talk',
#   'TWICE (트와이스)',
#   'BETWEEN 1&2',
#   '2022.08.26',
#   '댄스/팝',
#   'Dreamus',
#   'JYP엔터테인먼트'],
#  ['92',
#   'Bugs/Bugs92.jpg',
#   "I Ain't Worried",
#   'OneRepublic(원리퍼블릭)',
#   '탑건 : 매버릭 (Top Gun: Maverick) (영화 OST)',
#   '2022.05.27',
#   'OST',
#   '유니버설뮤직코리아',
#   'Interscope Records'],
#  ['93',
#   'Bugs/Bugs93.jpg',
#   '사랑해도 될까요',
#   '양다일',
#   '사랑해도 될까요',
#   '2023.01.15',
#   '발라드',
#   '카카오엔터테인먼트',
#   '방구석캐스팅'],
#  ['94',
#   'Bugs/Bugs94.jpg',
#   '눈이 오잖아(Feat.헤이즈)',
#   '이무진',
#   '눈이 오잖아(Feat.헤이즈)',
#   '2021.12.03',
#   '발라드',
#   '카카오엔터테인먼트',
#   '쇼플레이엔터테인먼트'],
#  ['95',
#   'Bugs/Bugs95.jpg',
#   '신호등',
#   '이무진',
#   '신호등',
#   '2021.05.14',
#   '댄스/팝',
#   '카카오엔터테인먼트',
#   '쇼플레이엔터테인먼트'],
#  ['96',
#   'Bugs/Bugs96.jpg',
#   'DICE',
#   'NMIXX',
#   'ENTWURF',
#   '2022.09.19',
#   '댄스/팝',
#   'Dreamus',
#   'JYP엔터테인먼트'],
#  ['97',
#   'Bugs/Bugs97.jpg',
#   'Beautiful Liar',
#   '몬스타엑스(Monsta X)',
#   'REASON',
#   '2023.01.09',
#   '댄스/팝',
#   '카카오엔터테인먼트',
#   '스타쉽엔터테인먼트'],
#  ['98',
#   'Bugs/Bugs98.jpg',
#   '니 번호가 뜨는 일',
#   '이예준',
#   '니 번호가 뜨는 일',
#   '2023.01.17',
#   '발라드',
#   '카카오엔터테인먼트',
#   '오늘의 선곡'],
#  ['99',
#   'Bugs/Bugs99.jpg',
#   'Love War (Feat. BE‘O)',
#   'YENA (최예나)',
#   'Love War',
#   '2023.01.16',
#   '알앤비/소울',
#   '지니뮤직, Stone Music Entertainment',
#   '위에화엔터테인먼트코리아'],
#  ['100',
#   'Bugs/Bugs100.jpg',
#   '마이웨이 (MY WAY) (Prod. R.Tee)',
#   '저스디스(JUSTHIS)',
#   '쇼미더머니 11 Episode 1',
#   '2022.12.03',
#   '랩/힙합',
#   '지니뮤직',
#   'Stone Music Entertainment']]

# %%
import requests
from bs4 import BeautifulSoup
import json
import os
os.environ.setdefault("DJANGO_SETTINGS_MODULE", "config.settings")

import django
django.setup()

from music.models import BugsWeekTop

def parse_music():
  header = {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/39.0.2171.95 Safari/537.36'}
  req = requests.get('https://music.bugs.co.kr/chart/track/week/total',headers = header)
  soup = BeautifulSoup(req.content,'html.parser')
  bugscharts = soup.select('#CHARTweek > table > tbody > tr')
  
  data = []
  # data = {}
  for idx, bugschart in enumerate(bugscharts):
    # 순위
    rank = bugschart.select('td > div.ranking > strong')[0].text
    # 앨범표지
    image = 'Bugs/Bugs{}.jpg'.format((idx+1))
    # 가수
    title = bugschart.select('th > p.title > a')[0].text
    # 곡 제목 찾기
    musician = bugschart.select('td > p.artist > a')[0].text
    # 앨범
    album = bugschart.select('td > a.album')[0].text
    data.append([rank,image,title,musician,album])
    # data[str(rank)] = {'rank':rank,'title':title,'musician':musician,'album':album}

  return data 
parse_music()
# Out:
# [['1', 'Bugs/Bugs1.jpg', 'Ditto', 'NewJeans', "NewJeans 'OMG'"],
#  ['2', 'Bugs/Bugs2.jpg', 'OMG', 'NewJeans', "NewJeans 'OMG'"],
#  ['3',
#   'Bugs/Bugs3.jpg',
#   'Hype Boy',
#   'NewJeans',
#   "NewJeans 1st EP 'New Jeans'"],
#  ['4',
#   'Bugs/Bugs4.jpg',
#   'VIBE (feat. Jimin of BTS)',
#   '태양',
#   'VIBE (feat. Jimin of BTS)'],
#  ['5',
#   'Bugs/Bugs5.jpg',
#   'Attention',
#   'NewJeans',
#   "NewJeans 1st EP 'New Jeans'"],
#  ['6',
#   'Bugs/Bugs6.jpg',
#   '사건의 지평선',
#   '윤하(Younha/ユンナ)',
#   "YOUNHA 6th Album Repackage 'END THEORY : Final Edition'"],
#  ['7', 'Bugs/Bugs7.jpg', 'ANTIFRAGILE', 'LE SSERAFIM (르세라핌)', 'ANTIFRAGILE'],
#  ['8', 'Bugs/Bugs8.jpg', 'After LIKE', 'IVE (아이브)', 'After LIKE'],
#  ['9',
#   'Bugs/Bugs9.jpg',
#   'Candy',
#   'NCT DREAM',
#   'Candy - Winter Special Mini Album'],
#  ['10',
#   'Bugs/Bugs10.jpg',
#   'Rush Hour (Feat. j-hope of BTS)',
#   'Crush',
#   'Rush Hour'],
#  ['11',
#   'Bugs/Bugs11.jpg',
#   'I Don’t Think That I Like Her',
#   'Charlie Puth(찰리 푸스)',
#   'I Don’t Think That I Like Her'],
#  ['12',
#   'Bugs/Bugs12.jpg',
#   'Dreamers [Music from the FIFA World Cup Qatar 2022 Official Soundtrack] (feat. FIFA Sound)',
#   '정국',
#   'Dreamers [Music from the FIFA World Cup Qatar 2022 Official Soundtrack]'],
#  ['13', 'Bugs/Bugs13.jpg', 'LOVE DIVE', 'IVE (아이브)', 'LOVE DIVE'],
#  ['14',
#   'Bugs/Bugs14.jpg',
#   'Cookie',
#   'NewJeans',
#   "NewJeans 1st EP 'New Jeans'"],
#  ['15',
#   'Bugs/Bugs15.jpg',
#   '오르트구름',
#   '윤하(Younha/ユンナ)',
#   "YOUNHA 6th Album 'END THEORY'"],
#  ['16', 'Bugs/Bugs16.jpg', 'Unholy', 'Sam Smith(샘 스미스)', 'Unholy'],
#  ['17',
#   'Bugs/Bugs17.jpg',
#   'Left and Right (Feat. Jung Kook of BTS)',
#   'Charlie Puth(찰리 푸스)',
#   'Left and Right (Feat. Jung Kook of BTS)'],
#  ['18', 'Bugs/Bugs18.jpg', 'WHEN I MOVE', '카라(Kara)', 'MOVE AGAIN'],
#  ['19', 'Bugs/Bugs19.jpg', 'Nxde', '(여자)아이들', 'I love'],
#  ['20',
#   'Bugs/Bugs20.jpg',
#   'NOT SORRY (Feat. pH-1) (Prod. by Slom)',
#   '이영지',
#   '쇼미더머니 11 Episode 3'],
#  ['21', 'Bugs/Bugs21.jpg', 'Shut Down', 'BLACKPINK', 'BORN PINK'],
#  ['22', 'Bugs/Bugs22.jpg', 'FEARLESS', 'LE SSERAFIM (르세라핌)', 'FEARLESS'],
#  ['23',
#   'Bugs/Bugs23.jpg',
#   '혼자서 걸어요 (Prod. by 나얼)',
#   '태연 (TAEYEON)',
#   '나얼 <Ballad Pop City>'],
#  ['24',
#   'Bugs/Bugs24.jpg',
#   'That That (prod. & feat. SUGA of BTS)',
#   '싸이 (PSY)',
#   '싸다9'],
#  ['25', 'Bugs/Bugs25.jpg', 'Dynamite', '방탄소년단', 'Dynamite (DayTime Version)'],
#  ['26',
#   'Bugs/Bugs26.jpg',
#   '새삥 (Prod. ZICO) (Feat. 호미들)',
#   '지코',
#   '스트릿 맨 파이터(SMF) Original Vol.3 (계급미션)'],
#  ['27', 'Bugs/Bugs27.jpg', 'Pink Venom', 'BLACKPINK', 'BORN PINK'],
#  ['28', 'Bugs/Bugs28.jpg', 'Monologue', '테이(Tei)', 'Monologue'],
#  ['29',
#   'Bugs/Bugs29.jpg',
#   '너의 모든 순간',
#   '성시경',
#   '별에서 온 그대 (SBS 수목드라마) OST - Part.7'],
#  ['30',
#   'Bugs/Bugs30.jpg',
#   'Made You Look',
#   'Meghan Trainor(메간 트레이너)',
#   "Takin' It Back"],
#  ['31', 'Bugs/Bugs31.jpg', 'Butter', '방탄소년단', 'Butter'],
#  ['32',
#   'Bugs/Bugs32.jpg',
#   '사랑인가 봐',
#   '멜로망스(MeloMance)',
#   '사랑인가 봐 (사내맞선 OST 스페셜 트랙)'],
#  ['33', 'Bugs/Bugs33.jpg', 'ELEVEN', 'IVE (아이브)', 'ELEVEN'],
#  ['34', 'Bugs/Bugs34.jpg', 'TOMBOY', '(여자)아이들', 'I NEVER DIE'],
#  ['35',
#   'Bugs/Bugs35.jpg',
#   'Say I Love You',
#   '우디(Woody)',
#   'Say I Love You (Re : WIND 4MEN Vol.04)'],
#  ['36',
#   'Bugs/Bugs36.jpg',
#   '친구로 지내다 보면 (Feat. 김민석 of 멜로망스)',
#   'BIG Naughty (서동현)',
#   '친구로 지내다 보면'],
#  ['37',
#   'Bugs/Bugs37.jpg',
#   '한 페이지가 될 수 있게',
#   'DAY6 (데이식스)',
#   'The Book of Us : Gravity'],
#  ['38',
#   'Bugs/Bugs38.jpg',
#   "That's Hilarious",
#   'Charlie Puth(찰리 푸스)',
#   "That's Hilarious"],
#  ['39',
#   'Bugs/Bugs39.jpg',
#   'Ay-Yo',
#   'NCT 127',
#   'Ay-Yo - The 4th Album Repackage'],
#  ['40', 'Bugs/Bugs40.jpg', '그댄 행복에 살텐데 (2022)', '최유리', '그댄 행복에 살텐데 (2022)'],
#  ['41', 'Bugs/Bugs41.jpg', '그라데이션', '10CM', '5.3'],
#  ['42',
#   'Bugs/Bugs42.jpg',
#   'Permission to Dance',
#   '방탄소년단',
#   'Butter / Permission to Dance'],
#  ['43', 'Bugs/Bugs43.jpg', '봄날', '방탄소년단', 'YOU NEVER WALK ALONE'],
#  ['44',
#   'Bugs/Bugs44.jpg',
#   'Dangerously',
#   'Charlie Puth(찰리 푸스)',
#   'Nine Track Mind (Deluxe Edition)'],
#  ['45', 'Bugs/Bugs45.jpg', '마지막 사랑', '신예영', '마지막 사랑'],
#  ['46', 'Bugs/Bugs46.jpg', '자격지심 (Feat. ZICO)', "BE'O (비오)", 'FIVE SENSES'],
#  ['47', 'Bugs/Bugs47.jpg', '해요 (2022)', '#안녕', '해요 (2022)'],
#  ['48', 'Bugs/Bugs48.jpg', 'Yet To Come', '방탄소년단', 'Proof'],
#  ['49', 'Bugs/Bugs49.jpg', 'My Universe', 'Coldplay(콜드플레이)', 'My Universe'],
#  ['50', 'Bugs/Bugs50.jpg', 'Hurt', 'NewJeans', "NewJeans 1st EP 'New Jeans'"],
#  ['51', 'Bugs/Bugs51.jpg', 'Christmas Tree', 'V', '그 해 우리는 OST Part.5'],
#  ['52',
#   'Bugs/Bugs52.jpg',
#   '다정히 내 이름을 부르면',
#   '경서예지',
#   '다정히 내 이름을 부르면 (경서예지 x 전건호)'],
#  ['53',
#   'Bugs/Bugs53.jpg',
#   '정이라고 하자 (Feat. 10CM)',
#   'BIG Naughty (서동현)',
#   '정이라고 하자'],
#  ['54', 'Bugs/Bugs54.jpg', '그때 그 순간 그대로 (그그그)', 'WSG워너비 (가야G)', 'WSG워너비 1집'],
#  ['55',
#   'Bugs/Bugs55.jpg',
#   '도깨비불 (Illusion)',
#   'aespa',
#   'Girls - The 2nd Mini Album'],
#  ['56', 'Bugs/Bugs56.jpg', 'STAY', 'The Kid LAROI', 'STAY'],
#  ['57',
#   'Bugs/Bugs57.jpg',
#   'When I Get Old',
#   'Christopher(크리스토퍼)',
#   'When I Get Old'],
#  ['58', 'Bugs/Bugs58.jpg', '달려라 방탄', '방탄소년단', 'Proof'],
#  ['59', 'Bugs/Bugs59.jpg', '취중고백', '김민석 (멜로망스)', '취중고백'],
#  ['60', 'Bugs/Bugs60.jpg', '딱 10CM만', '10CM', '딱 10CM만'],
#  ['61',
#   'Bugs/Bugs61.jpg',
#   '모든 날, 모든 순간 (Every day, Every Moment)',
#   '폴킴(Paul Kim)',
#   "'키스 먼저 할까요?' OST Part.3"],
#  ['62', 'Bugs/Bugs62.jpg', 'INVU', '태연 (TAEYEON)', 'INVU - The 3rd Album'],
#  ['63', 'Bugs/Bugs63.jpg', 'Impurities', 'LE SSERAFIM (르세라핌)', 'ANTIFRAGILE'],
#  ['64',
#   'Bugs/Bugs64.jpg',
#   'Anti-Hero',
#   'Taylor Swift(테일러 스위프트)',
#   'Midnights (3am Edition)'],
#  ['65', 'Bugs/Bugs65.jpg', 'Off My Face', 'Justin Bieber(저스틴 비버)', 'Justice'],
#  ['66', 'Bugs/Bugs66.jpg', '들꽃놀이 (with 조유진)', 'RM', 'Indigo'],
#  ['67',
#   'Bugs/Bugs67.jpg',
#   'Feel My Rhythm',
#   'Red Velvet (레드벨벳)',
#   '‘The ReVe Festival 2022 - Feel My Rhythm’'],
#  ['68', 'Bugs/Bugs68.jpg', 'strawberry moon', '아이유(IU)', 'strawberry moon'],
#  ['69', 'Bugs/Bugs69.jpg', '그대를 알고', '송하예', '그대를 알고'],
#  ['70', 'Bugs/Bugs70.jpg', '나의 X에게', '경서', '나의 X에게'],
#  ['71',
#   'Bugs/Bugs71.jpg',
#   '봄여름가을겨울 (Still Life)',
#   'BIGBANG (빅뱅)',
#   '봄여름가을겨울 (Still Life)'],
#  ['72', 'Bugs/Bugs72.jpg', '우린 그렇게 사랑해서', '강민경', '우린 그렇게 사랑해서'],
#  ['73', 'Bugs/Bugs73.jpg', 'Life Goes On', '방탄소년단', 'BE'],
#  ['74', 'Bugs/Bugs74.jpg', '내가 아니라도', '주호', '내가 아니라도'],
#  ['75',
#   'Bugs/Bugs75.jpg',
#   'Sugar Rush Ride',
#   '투모로우바이투게더',
#   '이름의 장: TEMPTATION'],
#  ['76', 'Bugs/Bugs76.jpg', '사랑은 늘 도망가', '임영웅', '신사와 아가씨 OST Part.2'],
#  ['77', 'Bugs/Bugs77.jpg', 'LOVE me', "BE'O (비오)", 'LOVE me'],
#  ['78', 'Bugs/Bugs78.jpg', 'STEP', '카라(Kara)', 'KARA 3rd Album STEP'],
#  ['79', 'Bugs/Bugs79.jpg', '주저하는 연인들을 위해', '잔나비', '전설'],
#  ['80', 'Bugs/Bugs80.jpg', 'The Astronaut', '진(Jin)', 'The Astronaut'],
#  ['81', 'Bugs/Bugs81.jpg', '드라마', '아이유(IU)', '조각집'],
#  ['82', 'Bugs/Bugs82.jpg', '보고싶었어', 'WSG워너비(4FIRE)', 'WSG워너비 1집'],
#  ['83', 'Bugs/Bugs83.jpg', '잘가요', '주호', '잘가요'],
#  ['84', 'Bugs/Bugs84.jpg', 'Next Level', 'aespa', 'Next Level'],
#  ['85', 'Bugs/Bugs85.jpg', 'Love story', '볼빨간사춘기', 'Seoul'],
#  ['86',
#   'Bugs/Bugs86.jpg',
#   '아픈 나를 (Prod. By 나얼)',
#   '성시경',
#   '나얼 <Ballad Pop City>'],
#  ['87', 'Bugs/Bugs87.jpg', '떠나보낼 준비해 둘걸 그랬어', '임한별', '떠나보낼 준비해 둘걸 그랬어'],
#  ['88',
#   'Bugs/Bugs88.jpg',
#   'Snowman',
#   'Sia(시아)',
#   'Everyday Is Christmas (Snowman Deluxe Edition)'],
#  ['89', 'Bugs/Bugs89.jpg', '팡파레', '다비치', 'Season Note'],
#  ['90',
#   'Bugs/Bugs90.jpg',
#   'FOREVER 1',
#   "소녀시대 (GIRLS' GENERATION)",
#   'FOREVER 1 - The 7th Album'],
#  ['91', 'Bugs/Bugs91.jpg', 'Talk that Talk', 'TWICE (트와이스)', 'BETWEEN 1&2'],
#  ['92',
#   'Bugs/Bugs92.jpg',
#   "I Ain't Worried",
#   'OneRepublic(원리퍼블릭)',
#   '탑건 : 매버릭 (Top Gun: Maverick) (영화 OST)'],
#  ['93', 'Bugs/Bugs93.jpg', '사랑해도 될까요', '양다일', '사랑해도 될까요'],
#  ['94', 'Bugs/Bugs94.jpg', '눈이 오잖아(Feat.헤이즈)', '이무진', '눈이 오잖아(Feat.헤이즈)'],
#  ['95', 'Bugs/Bugs95.jpg', '신호등', '이무진', '신호등'],
#  ['96', 'Bugs/Bugs96.jpg', 'DICE', 'NMIXX', 'ENTWURF'],
#  ['97', 'Bugs/Bugs97.jpg', 'Beautiful Liar', '몬스타엑스(Monsta X)', 'REASON'],
#  ['98', 'Bugs/Bugs98.jpg', '니 번호가 뜨는 일', '이예준', '니 번호가 뜨는 일'],
#  ['99', 'Bugs/Bugs99.jpg', 'Love War (Feat. BE‘O)', 'YENA (최예나)', 'Love War'],
#  ['100',
#   'Bugs/Bugs100.jpg',
#   '마이웨이 (MY WAY) (Prod. R.Tee)',
#   '저스디스(JUSTHIS)',
#   '쇼미더머니 11 Episode 1']]

# %%
import requests
from bs4 import BeautifulSoup
import json
import os
os.environ.setdefault("DJANGO_SETTINGS_MODULE", "config.settings")

import django
django.setup()

from music.models import BugsWeekTop

header = {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/39.0.2171.95 Safari/537.36'}
req = requests.get('https://music.bugs.co.kr/chart/track/week/total',headers = header)

  # 1차 크롤링
soup = BeautifulSoup(req.content,'html.parser')
bugscharts = soup.select('#CHARTweek > table > tbody > tr')
  
data = []
  # data = {}
for idx, bugschart in enumerate(bugscharts):
    # 순위
    rank = bugschart.select('td > div.ranking > strong')[0].text
    # 앨범표지
    image = 'Bugs/Bugs{}.jpg'.format((idx+1))
    # 가수
    title = bugschart.select('th > p.title > a')[0].text
    # 곡 제목 찾기
    musician = bugschart.select('td > p.artist > a')[0].text
    # 앨범
    album = bugschart.select('td > a.album')[0].text
    # 앨범 detail 정보
    album_link = bugschart.select_one('td > a.album').attrs['href']

    
    req = requests.get(album_link,headers = header)

    # 2차 크롤링
    soup1 = BeautifulSoup(req.content,'html.parser')
    album_info = soup1.select("#container > section.sectionPadding.summaryInfo.summaryAlbum > div > div.basicInfo > table > tbody")
    # released_at = album_info.select("tr:nth-child(3) > td > time")[0].text
    # genre = album_info.select('tr:nth-child(4) > td > a')[0].text
    # released_cop = album_info.select('tr:nth-child(7) > td')[0].text
    # planned_cop = album_info.select('tr:nth-child(6) > td')[0].text
    for album_info in album_info:
        # tr:nth-child(3) > td > time 발매일
        # tr:nth-child(4) > td > a 장르
        # 기획사 tr:nth-child(6) > td
        # 발매사 tr:nth-child(7) > td
        released_at = album_info.select("tr:nth-child(3) > td > time")[0].text
        genre = album_info.select('tr:nth-child(4) > td > a')[0].text
        released_cop = album_info.select('tr:nth-child(7) > td')[0].text
        planned_cop = album_info.select('tr:nth-child(6) > td')[0].text

        # 2차 크롤링 추가
        
    data = [rank,image,title,musician,album,released_at,genre,released_cop,planned_cop]
    print((data))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[27], line 58
#      55     # 2차 크롤링 추가
#      57 data = [rank,image,title,musician,album,released_at,genre,released_cop,planned_cop]
# ---> 58 print(dict(data))
#
# ValueError: dictionary update sequence element #0 has length 1; 2 is required

# %%
import requests
from bs4 import BeautifulSoup
import json
import os

header = {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/39.0.2171.95 Safari/537.36'}
req = requests.get('https://music.bugs.co.kr/album/4082425?wl_ref=list_tr_11_chart',headers = header)
soup = BeautifulSoup(req.content,'html.parser')
album_info = soup.select("#container > section.sectionPadding.summaryInfo.summaryAlbum > div > div.basicInfo > table > tbody")

for album_info in album_info:
    # tr:nth-child(3) > td > time 발매일
    # tr:nth-child(4) > td > a 장르
    # 기획사 tr:nth-child(6) > td
    # 발매사 tr:nth-child(7) > td
    released_at = album_info.select("tr:nth-child(3) > td > time")[0].text
    genre = album_info.select('tr:nth-child(4) > td > a')[0].text
    released_cop = album_info.select('tr:nth-child(7) > td')[0].text
    planned_cop = album_info.select('tr:nth-child(6) > td')[0].text

    print(released_at,genre,released_cop,planned_cop)
# Out:
# 2023.01.02 댄스/팝 YG PLUS ADOR
