# %%
import requests
from bs4 import BeautifulSoup
import json
import os
os.environ.setdefault("DJANGO_SETTINGS_MODULE", "config.settings")
import re

import django
django.setup()

from music.models import MelonWeekTop

def parse_music():
  header = {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/39.0.2171.95 Safari/537.36'}
  req = requests.get('https://www.melon.com/chart/week/index.htm',headers = header)
  soup = BeautifulSoup(req.content,'html.parser')
  meloncharts = soup.select('table > tbody > tr')
  
  data = []
  # data = {}
  for idx, melonchart in enumerate(meloncharts):
    # 순위
    rank = melonchart.select('div.wrap.t_center > span.rank ')[0].text
    # 앨범표지
    image = 'melon/melon{}.jpg'.format((idx+1))
    # 가수
    musician = melonchart.select('div.ellipsis.rank02 > span > a')[0].text
    # 곡 제목 찾기
    title = melonchart.select('div.ellipsis.rank01 > span > a')[0].text
    # 앨범
    album = melonchart.select('div.ellipsis.rank03 > a')[0].text
    # 앨범 detail
    album_link = melonchart.select_one('div.ellipsis.rank03 > a').attrs["href"]
    p = re.compile('[0-9]+')
    album_id = p.findall(album_link)    
    # https://www.melon.com/album/music.htm?albumId=album_id[0]
    
    req = requests.get(f'https://www.melon.com/album/music.htm?albumId={album_id[0]}',headers = header)
    soup1 = BeautifulSoup(req.content,'html.parser')
    album_info = soup1.select("#conts > div.section_info > div > div.entry > div.meta > dl.list")
    for album_info in album_info:
    # #conts > div.section_info > div > div.entry > div.meta > dl > dd:nth-child(2)
      released_at = album_info.select("dd:nth-child(2)")[0].text
      genre = album_info.select('dd:nth-child(4)')[0].text
      released_cop = album_info.select('dd:nth-child(6)')[0].text
      planned_cop = album_info.select('dd:nth-child(8)')[0].text



    # data.append([rank,image,title,musician,album,album_link])
    data.append([rank,image,title,musician,album,released_at,genre,released_cop,planned_cop])
    # ,released_at,genre,released_cop,planned_cop
    # data[str(rank)] = {'rank':rank,'title':title,'musician':musician,'album':album}

  return data

parse_music()
# Out:
# [['1',
#   'melon/melon1.jpg',
#   'Ditto',
#   'NewJeans',
#   "NewJeans 'OMG'",
#   '2023.01.02',
#   '댄스',
#   'YG PLUS',
#   'ADOR'],
#  ['2',
#   'melon/melon2.jpg',
#   'OMG',
#   'NewJeans',
#   "NewJeans 'OMG'",
#   '2023.01.02',
#   '댄스',
#   'YG PLUS',
#   'ADOR'],
#  ['3',
#   'melon/melon3.jpg',
#   'Hype boy',
#   'NewJeans',
#   "NewJeans 1st EP 'New Jeans'",
#   '2022.08.01',
#   '댄스, R&B/Soul',
#   'YG PLUS',
#   'ADOR'],
#  ['4',
#   'melon/melon4.jpg',
#   '사건의 지평선',
#   '윤하 (YOUNHA)',
#   "YOUNHA 6th Album Repackage 'END THEORY : Final Edition'",
#   '2022.03.30',
#   '록/메탈, 발라드, R&B/Soul',
#   '카카오엔터테인먼트',
#   'C9 Entertainment'],
#  ['5',
#   'melon/melon5.jpg',
#   'VIBE (feat. Jimin of BTS)',
#   '태양',
#   'VIBE (feat. Jimin of BTS)',
#   '2023.01.13',
#   '댄스',
#   'YG PLUS',
#   'THEBLACKLABEL'],
#  ['6',
#   'melon/melon6.jpg',
#   'ANTIFRAGILE',
#   'LE SSERAFIM (르세라핌)',
#   'ANTIFRAGILE',
#   '2022.10.17',
#   '댄스, 발라드, R&B/Soul, 록/메탈',
#   'YG PLUS',
#   '쏘스뮤직'],
#  ['7',
#   'melon/melon7.jpg',
#   'Attention',
#   'NewJeans',
#   "NewJeans 1st EP 'New Jeans'",
#   '2022.08.01',
#   '댄스, R&B/Soul',
#   'YG PLUS',
#   'ADOR'],
#  ['8',
#   'melon/melon8.jpg',
#   'After LIKE',
#   'IVE (아이브)',
#   'After LIKE',
#   '2022.08.22',
#   '댄스',
#   '카카오엔터테인먼트',
#   '스타쉽엔터테인먼트'],
#  ['9',
#   'melon/melon9.jpg',
#   'Candy',
#   'NCT DREAM',
#   'Candy - Winter Special Mini Album',
#   '2022.12.16',
#   '댄스, R&B/Soul, 발라드',
#   'Dreamus',
#   'SM ENTERTAINMENT'],
#  ['10',
#   'melon/melon10.jpg',
#   'Nxde',
#   '(여자)아이들',
#   'I love',
#   '2022.10.17',
#   '록/메탈, 댄스, 랩/힙합, R&B/Soul',
#   '카카오엔터테인먼트',
#   '큐브 엔터테인먼트'],
#  ['11',
#   'melon/melon11.jpg',
#   'NOT SORRY (Feat. pH-1) (Prod. by Slom)',
#   '이영지',
#   '쇼미더머니 11 Episode 3',
#   '2022.12.17',
#   '랩/힙합',
#   '지니뮤직',
#   'Stone Music Entertainment'],
#  ['12',
#   'melon/melon12.jpg',
#   'LOVE DIVE',
#   'IVE (아이브)',
#   'LOVE DIVE',
#   '2022.04.05',
#   '댄스',
#   '카카오엔터테인먼트',
#   '스타쉽엔터테인먼트'],
#  ['13',
#   'melon/melon13.jpg',
#   'Sugar Rush Ride',
#   '투모로우바이투게더',
#   '이름의 장: TEMPTATION',
#   '2023.01.27',
#   '댄스, 랩/힙합, R&B/Soul, 록/메탈',
#   'YG PLUS',
#   'BIGHIT MUSIC'],
#  ['14',
#   'melon/melon14.jpg',
#   'Monologue',
#   '테이',
#   'Monologue',
#   '2022.09.18',
#   '발라드',
#   '카카오엔터테인먼트',
#   '방구석캐스팅'],
#  ['15',
#   'melon/melon15.jpg',
#   '새삥 (Prod. ZICO) (Feat. 호미들)',
#   '지코 (ZICO)',
#   '스트릿 맨 파이터(SMF) Original Vol.3 (계급미션)',
#   '2022.09.06',
#   '랩/힙합',
#   '지니뮤직',
#   'Stone Music Entertainment'],
#  ['16',
#   'melon/melon16.jpg',
#   '너의 모든 순간',
#   '성시경',
#   '별에서 온 그대 OST Part.7',
#   '2014.02.12',
#   '발라드, 국내드라마',
#   'NHN벅스',
#   '㈜SBS콘텐츠허브'],
#  ['17',
#   'melon/melon17.jpg',
#   'Cookie',
#   'NewJeans',
#   "NewJeans 1st EP 'New Jeans'",
#   '2022.08.01',
#   '댄스, R&B/Soul',
#   'YG PLUS',
#   'ADOR'],
#  ['18',
#   'melon/melon18.jpg',
#   "I Don't Think That I Like Her",
#   'Charlie Puth',
#   'CHARLIE',
#   '2022.10.07',
#   'POP',
#   '워너뮤직',
#   'Atlantic Records'],
#  ['19',
#   'melon/melon19.jpg',
#   '마지막 사랑',
#   '신예영',
#   '마지막 사랑',
#   '2023.01.12',
#   '발라드',
#   '카카오엔터테인먼트',
#   '투플원엔터테인먼트, (주)제나두엔터테인먼트'],
#  ['20',
#   'melon/melon20.jpg',
#   '사랑인가 봐',
#   '멜로망스',
#   '사랑인가 봐 (사내맞선 OST 스페셜 트랙)',
#   '2022.02.18',
#   '국내드라마, 발라드',
#   '카카오엔터테인먼트',
#   '플렉스엠'],
#  ['21',
#   'melon/melon21.jpg',
#   '해요 (2022)',
#   '#안녕',
#   '해요 (2022)',
#   '2022.06.07',
#   '발라드, 인디음악',
#   '지니뮤직',
#   '일팔 프로젝트'],
#  ['22',
#   'melon/melon22.jpg',
#   '사랑은 늘 도망가',
#   '임영웅',
#   '신사와 아가씨 OST Part.2',
#   '2021.10.11',
#   '국내드라마, 발라드',
#   '(주)엔에이치엔벅스',
#   '모스트콘텐츠'],
#  ['23',
#   'melon/melon23.jpg',
#   'Shut Down',
#   'BLACKPINK',
#   'BORN PINK',
#   '2022.09.16',
#   '랩/힙합, 댄스, 발라드',
#   'YG PLUS',
#   'YG Entertainment'],
#  ['24',
#   'melon/melon24.jpg',
#   '그대를 알고',
#   '송하예',
#   '그대를 알고',
#   '2022.12.13',
#   '발라드',
#   '카카오엔터테인먼트',
#   '디스튜디오'],
#  ['25',
#   'melon/melon25.jpg',
#   '마이웨이 (MY WAY) (Prod. R.Tee)',
#   '저스디스 (JUSTHIS)',
#   '쇼미더머니 11 Episode 1',
#   '2022.12.03',
#   '랩/힙합',
#   '지니뮤직',
#   'Stone Music Entertainment'],
#  ['26',
#   'melon/melon26.jpg',
#   'Say I Love You',
#   '우디 (Woody)',
#   'Say I Love You (Re : WIND 4MEN Vol.04)',
#   '2022.12.21',
#   '발라드',
#   '지니뮤직',
#   '메이저나인'],
#  ['27',
#   'melon/melon27.jpg',
#   'Rush Hour (Feat. j-hope of BTS)',
#   'Crush',
#   'Rush Hour',
#   '2022.09.22',
#   'R&B/Soul',
#   'Dreamus',
#   '피네이션'],
#  ['28',
#   'melon/melon28.jpg',
#   'Pink Venom',
#   'BLACKPINK',
#   'BORN PINK',
#   '2022.09.16',
#   '랩/힙합, 댄스, 발라드',
#   'YG PLUS',
#   'YG Entertainment'],
#  ['29',
#   'melon/melon29.jpg',
#   'TOMBOY',
#   '(여자)아이들',
#   'I NEVER DIE',
#   '2022.03.14',
#   '록/메탈, R&B/Soul, 댄스, 랩/힙합',
#   '카카오엔터테인먼트',
#   '큐브 엔터테인먼트'],
#  ['30',
#   'melon/melon30.jpg',
#   '잘가요',
#   '주호',
#   '잘가요',
#   '2022.12.04',
#   '발라드',
#   '워너뮤직',
#   '레이벡스'],
#  ['31',
#   'melon/melon31.jpg',
#   '내가 아니라도',
#   '주호',
#   '내가 아니라도',
#   '2022.03.25',
#   '발라드',
#   '워너뮤직',
#   'IN A MILLION'],
#  ['32',
#   'melon/melon32.jpg',
#   '그때 그 순간 그대로 (그그그)',
#   'WSG워너비 (가야G)',
#   'WSG워너비 1집',
#   '2022.07.09',
#   '발라드, 댄스, R&B/Soul',
#   '카카오엔터테인먼트',
#   '문화방송'],
#  ['33',
#   'melon/melon33.jpg',
#   'FEARLESS',
#   'LE SSERAFIM (르세라핌)',
#   'FEARLESS',
#   '2022.05.02',
#   '댄스, 발라드',
#   'YG PLUS',
#   '쏘스뮤직'],
#  ['34',
#   'melon/melon34.jpg',
#   '취중고백',
#   '김민석 (멜로망스)',
#   '취중고백',
#   '2021.12.19',
#   '발라드',
#   '워너뮤직',
#   '프로젝트 리본'],
#  ['35',
#   'melon/melon35.jpg',
#   '네가 보고 싶은 건 자연스러운 거겠지',
#   '신예영',
#   '혼잣말 獨白',
#   '2023.01.24',
#   '발라드',
#   '카카오엔터테인먼트',
#   '주식회사 셀러빗(CELEBIT)'],
#  ['36',
#   'melon/melon36.jpg',
#   '그댄 행복에 살텐데 (2022)',
#   '최유리',
#   '그댄 행복에 살텐데 (2022)',
#   '2022.12.27',
#   '발라드, 인디음악',
#   'Dreamus',
#   '일팔 프로젝트'],
#  ['37',
#   'melon/melon37.jpg',
#   '그라데이션',
#   '10CM',
#   '5.3',
#   '2022.07.03',
#   '포크/블루스, 인디음악',
#   '카카오엔터테인먼트',
#   '매직스트로베리사운드'],
#  ['38',
#   'melon/melon38.jpg',
#   '정이라고 하자 (Feat. 10CM)',
#   'BIG Naughty (서동현)',
#   '정이라고 하자',
#   '2022.04.20',
#   'R&B/Soul',
#   '카카오엔터테인먼트',
#   'H1GHR MUSIC RECORDS'],
#  ['39',
#   'melon/melon39.jpg',
#   '자격지심 (Feat. ZICO)',
#   "BE'O (비오)",
#   'FIVE SENSES',
#   '2022.09.29',
#   '랩/힙합, R&B/Soul, 록/메탈',
#   '카카오엔터테인먼트',
#   '빅플래닛메이드, SWING ENTERTAINMENT, 페임어스 엔터테인먼트'],
#  ['40',
#   'melon/melon40.jpg',
#   "That's Hilarious",
#   'Charlie Puth',
#   'CHARLIE',
#   '2022.10.07',
#   'POP',
#   '워너뮤직',
#   'Atlantic Records'],
#  ['41',
#   'melon/melon41.jpg',
#   '니 번호가 뜨는 일',
#   '이예준',
#   '니 번호가 뜨는 일',
#   '2023.01.17',
#   '발라드',
#   '카카오엔터테인먼트',
#   '오늘의 선곡'],
#  ['42',
#   'melon/melon42.jpg',
#   '딱 10CM만',
#   '10CM',
#   '딱 10CM만',
#   '2022.09.25',
#   'R&B/Soul',
#   '카카오엔터테인먼트',
#   'MAGIC STRAWBERRY SOUND, H1GHR MUSIC RECORDS'],
#  ['43',
#   'melon/melon43.jpg',
#   '다정히 내 이름을 부르면',
#   '경서예지',
#   '다정히 내 이름을 부르면 (경서예지 x 전건호)',
#   '2021.05.19',
#   '발라드',
#   '카카오엔터테인먼트',
#   '에버그로우'],
#  ['44',
#   'melon/melon44.jpg',
#   'ELEVEN',
#   'IVE (아이브)',
#   'ELEVEN',
#   '2021.12.01',
#   '댄스',
#   '카카오엔터테인먼트',
#   '스타쉽엔터테인먼트'],
#  ['45',
#   'melon/melon45.jpg',
#   '모든 날, 모든 순간 (Every day, Every Moment)',
#   '폴킴',
#   "'키스 먼저 할까요?' OST Part.3",
#   '2018.03.20',
#   '발라드, 국내드라마',
#   'Dreamus',
#   'SM Entertainment'],
#  ['46',
#   'melon/melon46.jpg',
#   'Dreamers [Music from the FIFA World Cup Qatar 2022 Official Soundtrack] (Feat. FIFA Sound)',
#   '정국',
#   'Dreamers [Music from the FIFA World Cup Qatar 2022 Official Soundtrack]',
#   '2022.11.20',
#   'POP',
#   'FUGA',
#   'Katara Studios | 2101 Records under exclusive license to Un..'],
#  ['47',
#   'melon/melon47.jpg',
#   '나의 X에게',
#   '경서',
#   '나의 X에게',
#   '2022.04.24',
#   '발라드',
#   '카카오엔터테인먼트',
#   '꿈의엔진'],
#  ['48',
#   'melon/melon48.jpg',
#   '오르트구름',
#   '윤하 (YOUNHA)',
#   "YOUNHA 6th Album 'END THEORY'",
#   '2021.11.16',
#   '록/메탈, 발라드, R&B/Soul',
#   '카카오엔터테인먼트',
#   'C9 Entertainment'],
#  ['49',
#   'melon/melon49.jpg',
#   'Ay-Yo',
#   'NCT 127',
#   'Ay-Yo - The 4th Album Repackage',
#   '2023.01.30',
#   '댄스, R&B/Soul, 랩/힙합, 발라드',
#   'Dreamus',
#   'SM ENTERTAINMENT'],
#  ['50',
#   'melon/melon50.jpg',
#   '사랑해도 될까요',
#   '양다일',
#   '사랑해도 될까요',
#   '2023.01.15',
#   '발라드',
#   '카카오엔터테인먼트',
#   '방구석캐스팅'],
#  ['51',
#   'melon/melon51.jpg',
#   '우리들의 블루스',
#   '임영웅',
#   'IM HERO',
#   '2022.05.02',
#   '발라드, 성인가요/트로트, 포크/블루스, 랩/힙합, 록/메탈, 재즈',
#   'Dreamus',
#   '물고기뮤직'],
#  ['52',
#   'melon/melon52.jpg',
#   'STAY',
#   'The Kid LAROI',
#   'Stay',
#   '2021.07.09',
#   'POP',
#   'Sony Music',
#   'Columbia'],
#  ['53',
#   'melon/melon53.jpg',
#   'Unholy',
#   'Sam Smith',
#   'Gloria',
#   '2023.01.27',
#   'POP',
#   'Universal Music Group',
#   'EMI'],
#  ['54',
#   'melon/melon54.jpg',
#   'WHEN I MOVE',
#   '카라',
#   'MOVE AGAIN',
#   '2022.11.29',
#   '발라드, 댄스',
#   'Dreamus',
#   '㈜RBW'],
#  ['55',
#   'melon/melon55.jpg',
#   '보고싶었어',
#   'WSG워너비(4FIRE)',
#   'WSG워너비 1집',
#   '2022.07.09',
#   '발라드, 댄스, R&B/Soul',
#   '카카오엔터테인먼트',
#   '문화방송'],
#  ['56',
#   'melon/melon56.jpg',
#   '떠나보낼 준비해 둘걸 그랬어',
#   '임한별',
#   '떠나보낼 준비해 둘걸 그랬어',
#   '2022.10.18',
#   '발라드',
#   '카카오엔터테인먼트',
#   '오늘의 선곡'],
#  ['57',
#   'melon/melon57.jpg',
#   '첫사랑',
#   '백아',
#   '첫사랑',
#   '2018.10.11',
#   '인디음악, 포크/블루스',
#   '포크라노스',
#   'Baek A'],
#  ['58',
#   'melon/melon58.jpg',
#   'LOVE me',
#   "BE'O (비오)",
#   'LOVE me',
#   '2022.04.12',
#   '랩/힙합',
#   '카카오엔터테인먼트',
#   'BPM ENTERTAINMENT, SWING ENTERTAINMENT, 페임어스 엔터테인먼..'],
#  ['59',
#   'melon/melon59.jpg',
#   '밤하늘의 별을(2020)',
#   '경서',
#   '밤하늘의 별을(2020)',
#   '2020.11.14',
#   '발라드',
#   '카카오엔터테인먼트',
#   '꿈의엔진'],
#  ['60',
#   'melon/melon60.jpg',
#   'That That (prod. & feat. SUGA of BTS)',
#   '싸이 (PSY)',
#   '싸다9',
#   '2022.04.29',
#   '랩/힙합, 댄스, 일렉트로니카',
#   'Dreamus',
#   'P NATION'],
#  ['61',
#   'melon/melon61.jpg',
#   '봄여름가을겨울 (Still Life)',
#   'BIGBANG (빅뱅)',
#   '봄여름가을겨울 (Still Life)',
#   '2022.04.05',
#   '록/메탈',
#   'YG PLUS',
#   'YG Entertainment'],
#  ['62',
#   'melon/melon62.jpg',
#   'Dynamite',
#   '방탄소년단',
#   'Dynamite (DayTime Version)',
#   '2020.08.21',
#   '댄스',
#   'YG PLUS',
#   'BIGHIT MUSIC'],
#  ['63',
#   'melon/melon63.jpg',
#   '다시 만날 수 있을까',
#   '임영웅',
#   'IM HERO',
#   '2022.05.02',
#   '발라드, 성인가요/트로트, 포크/블루스, 랩/힙합, 록/메탈, 재즈',
#   'Dreamus',
#   '물고기뮤직'],
#  ['64',
#   'melon/melon64.jpg',
#   '가슴으로 운다',
#   '김연지',
#   '가슴으로 운다',
#   '2023.01.11',
#   '발라드',
#   '카카오엔터테인먼트',
#   '방구석캐스팅'],
#  ['65',
#   'melon/melon65.jpg',
#   '내 기쁨은 너가 벤틀리를 끄는 거야',
#   '김승민',
#   'PROTOTYPE RESEARCH #0063',
#   '2021.10.19',
#   '랩/힙합',
#   '지니뮤직, Stone Music Entertainment',
#   '뷰티플노이즈'],
#  ['66',
#   'melon/melon66.jpg',
#   'Devil by the Window',
#   '투모로우바이투게더',
#   '이름의 장: TEMPTATION',
#   '2023.01.27',
#   '댄스, 랩/힙합, R&B/Soul, 록/메탈',
#   'YG PLUS',
#   'BIGHIT MUSIC'],
#  ['67',
#   'melon/melon67.jpg',
#   '친구로 지내다 보면 (Feat. 김민석 of 멜로망스)',
#   'BIG Naughty (서동현)',
#   '친구로 지내다 보면',
#   '2023.01.29',
#   'R&B/Soul',
#   '카카오엔터테인먼트',
#   'H1GHR MUSIC RECORDS'],
#  ['68',
#   'melon/melon68.jpg',
#   '주저하는 연인들을 위해',
#   '잔나비',
#   '전설',
#   '2019.03.13',
#   '록/메탈, 인디음악',
#   '카카오엔터테인먼트',
#   '페포니 뮤직'],
#  ['69',
#   'melon/melon69.jpg',
#   '새벽에 걸려온 너의 전화는',
#   '한동근',
#   '미련을 말하는',
#   '2022.07.31',
#   '발라드',
#   '카카오엔터테인먼트',
#   '말하는'],
#  ['70',
#   'melon/melon70.jpg',
#   '눈이 오잖아(Feat.헤이즈)',
#   '이무진',
#   '눈이 오잖아(Feat.헤이즈)',
#   '2021.12.03',
#   '발라드',
#   '카카오엔터테인먼트',
#   '쇼플레이엔터테인먼트'],
#  ['71',
#   'melon/melon71.jpg',
#   '우린 그렇게 사랑해서',
#   '강민경 (다비치)',
#   '우린 그렇게 사랑해서',
#   '2022.09.26',
#   '발라드',
#   '지니뮤직, Stone Music Entertainment',
#   'WAKEONE, 페포니뮤직'],
#  ['72',
#   'melon/melon72.jpg',
#   '이제 나만 믿어요',
#   '임영웅',
#   '내일은 미스터트롯 우승자 특전곡',
#   '2020.04.03',
#   '성인가요/트로트',
#   '카카오엔터테인먼트',
#   'TV CHOSUN'],
#  ['73',
#   'melon/melon73.jpg',
#   'Butter',
#   '방탄소년단',
#   'Butter',
#   '2021.05.21',
#   '댄스',
#   'YG PLUS',
#   'BIGHIT MUSIC'],
#  ['74',
#   'melon/melon74.jpg',
#   '네버랜드를 떠나며',
#   '투모로우바이투게더',
#   '이름의 장: TEMPTATION',
#   '2023.01.27',
#   '댄스, 랩/힙합, R&B/Soul, 록/메탈',
#   'YG PLUS',
#   'BIGHIT MUSIC'],
#  ['75',
#   'melon/melon75.jpg',
#   '봄날',
#   '방탄소년단',
#   'YOU NEVER WALK ALONE',
#   '2017.02.13',
#   '랩/힙합, 발라드',
#   'YG PLUS',
#   'BIGHIT MUSIC'],
#  ['76',
#   'melon/melon76.jpg',
#   'Love story',
#   '볼빨간사춘기',
#   'Seoul',
#   '2022.04.20',
#   '인디음악, 포크/블루스, 발라드, 록/메탈',
#   '(주)엔에이치엔벅스',
#   '쇼파르엔터테인먼트'],
#  ['77',
#   'melon/melon77.jpg',
#   '그 겨울이 잠든 거리에서',
#   '경서예지',
#   '그 겨울이 잠든 거리에서 (경서예지 x 전건호)',
#   '2022.12.11',
#   '발라드',
#   '카카오엔터테인먼트',
#   '에버그로우'],
#  ['78',
#   'melon/melon78.jpg',
#   'Off My Face',
#   'Justin Bieber',
#   'Justice (The Complete Edition)',
#   '2021.10.08',
#   'POP',
#   'Universal Music Group',
#   'RBMG/Def Jam'],
#  ['79',
#   'melon/melon79.jpg',
#   'Tinnitus (돌멩이가 되고 싶어)',
#   '투모로우바이투게더',
#   '이름의 장: TEMPTATION',
#   '2023.01.27',
#   '댄스, 랩/힙합, R&B/Soul, 록/메탈',
#   'YG PLUS',
#   'BIGHIT MUSIC'],
#  ['80',
#   'melon/melon80.jpg',
#   'London Boy',
#   '임영웅',
#   'Polaroid',
#   '2022.11.15',
#   '록/메탈',
#   'Dreamus',
#   '물고기뮤직'],
#  ['81',
#   'melon/melon81.jpg',
#   '무지개',
#   '임영웅',
#   'IM HERO',
#   '2022.05.02',
#   '발라드, 성인가요/트로트, 포크/블루스, 랩/힙합, 록/메탈, 재즈',
#   'Dreamus',
#   '물고기뮤직'],
#  ['82',
#   'melon/melon82.jpg',
#   'Happy Fools (feat. Coi Leray)',
#   '투모로우바이투게더',
#   '이름의 장: TEMPTATION',
#   '2023.01.27',
#   '댄스, 랩/힙합, R&B/Soul, 록/메탈',
#   'YG PLUS',
#   'BIGHIT MUSIC'],
#  ['83',
#   'melon/melon83.jpg',
#   '위하여 (We Higher) (Prod. GroovyRoom)',
#   '그루비룸 (GroovyRoom)',
#   '쇼미더머니 11 Episode 1',
#   '2022.12.03',
#   '랩/힙합',
#   '지니뮤직',
#   'Stone Music Entertainment'],
#  ['84',
#   'melon/melon84.jpg',
#   '도깨비불 (Illusion)',
#   'aespa',
#   'Girls - The 2nd Mini Album',
#   '2022.07.08',
#   '댄스, 발라드',
#   'Dreamus',
#   'SM ENTERTAINMENT'],
#  ['85',
#   'melon/melon85.jpg',
#   'FOREVER 1',
#   "소녀시대 (GIRLS' GENERATION)",
#   'FOREVER 1 - The 7th Album',
#   '2022.08.05',
#   '댄스, R&B/Soul, 발라드',
#   'Dreamus',
#   'SM ENTERTAINMENT'],
#  ['86',
#   'melon/melon86.jpg',
#   '희재',
#   '성시경',
#   '국화꽃 향기 OST',
#   '2003.02.01',
#   '국내영화, POP, 발라드',
#   'Taewon Entertainment',
#   '-'],
#  ['87',
#   'melon/melon87.jpg',
#   'Snowman',
#   'Sia',
#   'Everyday Is Christmas (Snowman Deluxe Edition)',
#   '2022.12.30',
#   'POP',
#   '워너뮤직',
#   'Monkey Puzzle, Atlantic'],
#  ['88',
#   'melon/melon88.jpg',
#   '아버지',
#   '임영웅',
#   'IM HERO',
#   '2022.05.02',
#   '발라드, 성인가요/트로트, 포크/블루스, 랩/힙합, 록/메탈, 재즈',
#   'Dreamus',
#   '물고기뮤직'],
#  ['89',
#   'melon/melon89.jpg',
#   'Polaroid',
#   '임영웅',
#   'Polaroid',
#   '2022.11.15',
#   '록/메탈',
#   'Dreamus',
#   '물고기뮤직'],
#  ['90',
#   'melon/melon90.jpg',
#   'Permission to Dance',
#   '방탄소년단',
#   'Butter / Permission to Dance',
#   '2021.07.09',
#   '댄스',
#   'YG PLUS',
#   'BIGHIT MUSIC'],
#  ['91',
#   'melon/melon91.jpg',
#   'Dangerously',
#   'Charlie Puth',
#   'Nine Track Mind (Deluxe Edition)',
#   '2016.11.11',
#   'POP',
#   '워너뮤직',
#   'Artist Partner'],
#  ['92',
#   'melon/melon92.jpg',
#   '아픈 나를 (Prod. By 나얼)',
#   '성시경',
#   '나얼 <Ballad Pop City>',
#   '2022.12.27',
#   '발라드',
#   '카카오엔터테인먼트',
#   '롱플레이뮤직'],
#  ['93',
#   'melon/melon93.jpg',
#   '내 손을 잡아',
#   '아이유',
#   '최고의 사랑 OST Part.4',
#   '2011.05.25',
#   '발라드, 국내드라마',
#   '카카오엔터테인먼트',
#   '더그루브엔터테인먼트'],
#  ['94',
#   'melon/melon94.jpg',
#   '신호등',
#   '이무진',
#   '신호등',
#   '2021.05.14',
#   '록/메탈',
#   '카카오엔터테인먼트',
#   '쇼플레이엔터테인먼트'],
#  ['95',
#   'melon/melon95.jpg',
#   'A bientot',
#   '임영웅',
#   'IM HERO',
#   '2022.05.02',
#   '발라드, 성인가요/트로트, 포크/블루스, 랩/힙합, 록/메탈, 재즈',
#   'Dreamus',
#   '물고기뮤직'],
#  ['96',
#   'melon/melon96.jpg',
#   '인생찬가',
#   '임영웅',
#   'IM HERO',
#   '2022.05.02',
#   '발라드, 성인가요/트로트, 포크/블루스, 랩/힙합, 록/메탈, 재즈',
#   'Dreamus',
#   '물고기뮤직'],
#  ['97',
#   'melon/melon97.jpg',
#   '미운오리새끼 (Feat. 선우정아, BOBBY) (Prod. R.Tee)',
#   '허성현 (Huh)',
#   '쇼미더머니 11 Semi Final',
#   '2022.12.24',
#   '랩/힙합',
#   '지니뮤직',
#   'Stone Music Entertainment'],
#  ['98',
#   'melon/melon98.jpg',
#   '혼자서 걸어요 (Prod. by 나얼)',
#   '태연 (TAEYEON)',
#   '나얼 <Ballad Pop City>',
#   '2023.02.02',
#   '발라드',
#   '카카오엔터테인먼트',
#   '롱플레이뮤직'],
#  ['99',
#   'melon/melon99.jpg',
#   'Yet To Come',
#   '방탄소년단',
#   'Proof',
#   '2022.06.10',
#   '랩/힙합, 댄스, R&B/Soul',
#   'YG PLUS',
#   'BIGHIT MUSIC'],
#  ['100',
#   'melon/melon100.jpg',
#   '눈 (EYE) (Feat. BIG Naughty, 저스디스 (JUSTHIS)) (Prod. R.Tee)',
#   '던말릭 (DON MALIK)',
#   '쇼미더머니 11 Episode 3',
#   '2022.12.17',
#   '랩/힙합',
#   '지니뮤직',
#   'Stone Music Entertainment']]

# %%
import requests
from bs4 import BeautifulSoup
import json
import os

header = {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/39.0.2171.95 Safari/537.36'}
req = requests.get('https://www.melon.com/album/music.htm?albumId=11127145',headers = header)
soup = BeautifulSoup(req.content,'html.parser')
album_info = soup.select("#conts > div.section_info > div > div.entry > div.meta > dl.list")

for album_info in album_info:
    # #conts > div.section_info > div > div.entry > div.meta > dl > dd:nth-child(2)
    released_at = album_info.select("dd:nth-child(2)")[0].text
    genre = album_info.select('dd:nth-child(4)')[0].text
    released_cop = album_info.select('dd:nth-child(6)')[0].text
    planned_cop = album_info.select('dd:nth-child(8)')[0].text

    print(released_at,genre,released_cop,planned_cop)
# Out:
# 2023.01.02 댄스 YG PLUS ADOR
